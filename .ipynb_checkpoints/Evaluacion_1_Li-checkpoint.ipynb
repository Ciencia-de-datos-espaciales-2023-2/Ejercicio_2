# %% [markdown]
# # Evaluación 1
#
# Se han seleccionado tres fuentes, cada una relacionada con la temática de los premios Nobel de Química:
# - [Fuente 1](https://en.wikipedia.org/wiki/List_of_Nobel_laureates_in_Chemistry): Tabla con los ganadores de los premios Nobel en Química, clasificados por año, nombre y país de procedencia. Cabe notar que, en caso el ganador cuente con varias nacionalidades, se reporta más de un país y se han limpiado los datos para incluir únicamente el país de nacimiento.
#
# - [Fuente 2](https://en.wikipedia.org/wiki/List_of_nominees_for_the_Nobel_Prize_in_Chemistry): Nominados al premio Nobel de Química desde 1901 a 1970. El Comité Noruego del Nobel revela la lista de nominados hasta 50 años después de la fecha de nominación. Por esta razón, hasta la fecha, se cuenta con la lista oficial de nominados hasta 1973. Sin embargo, en la fuente que se empleará, solo se tiene información hasta 1970.
#
# - [Fuente 3](https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_university_affiliation): Tabla con todos los ganadores de los premios Nobel, clasificados acorde a su afiliación a determinado instituto o universidad. Se deberá limpiar la tabla para filtrar solo los ganadores correspondientes al premio Nobel de Química.
#
# Se han limpiado las fuentes para obtener tres DataFrames (DFs) con las siguientes variables:
# - Fuente 1: **'Year_of_award', 'Laureate', 'Rationale', 'Birth_year', 'Death_year','Country_of_birth'.**
# - Fuente 2: 'Years_Nominated', **'Nominees'**
# - Fuente 3: 'Laureate', 'Year_of_award', **'Affiliation'**
#
# *Nota*: Se encuentran resaltadas las variables que se conservarán en el DataFrame resultante de la unión de las tres y que se unirá con el archivo adjunto (country_isos.xlsx)

# %% [markdown]
# ## a) Fuente 1: "Laureates"

# %%
import pandas as pd

LaureatesLink="https://en.wikipedia.org/wiki/List_of_Nobel_laureates_in_Chemistry"
Laureates=pd.read_html(LaureatesLink,header=0,flavor='bs4')
type(Laureates)
# Out:
# list

# %%
len(Laureates)
# Out:
# 8

# %%
Laureates=pd.read_html(LaureatesLink,header=0,flavor='bs4')
Laureates_DF=Laureates[0]
Laureates_DF
# Out:
#      Year Image                               Laureate[A]      Country[B]  \
# 0    1901   NaN  Jacobus Henricus van 't Hoff (1852–1911)     Netherlands
# 1    1902   NaN          Hermann Emil Fischer (1852–1919)         Germany
# 2    1903   NaN       Svante August Arrhenius (1859–1927)          Sweden
# 3    1904   NaN            Sir William Ramsay (1852–1916)  United Kingdom
# 4    1905   NaN              Adolf von Baeyer (1835–1917)         Germany
# ..    ...   ...                                       ...             ...
# 197  2022   NaN                   Morten Meldal (b. 1954)         Denmark
# 198  2022   NaN              K. Barry Sharpless (b. 1941)   United States
# 199  2023   NaN               Moungi G. Bawendi (b. 1961)   United States
# 200  2023   NaN                   Louis E. Brus (b. 1943)   United States
# 201  2023   NaN                   Alexey Ekimov (b. 1945)          Russia
#
#                                           Rationale[C]    Ref
# 0    "[for his] discovery of the laws of chemical d...   [18]
# 1       "[for] his work on sugar and purine syntheses"   [19]
# 2      "[for] his electrolytic theory of dissociation"   [20]
# 3    "[for his] discovery of the inert gaseous elem...   [21]
# 4    "[for] the advancement of organic chemistry an...   [22]
# ..                                                 ...    ...
# 197  "for the development of click chemistry and bi...  [126]
# 198  "for the development of click chemistry and bi...  [126]
# 199  "for the discovery and synthesis of quantum dots"  [127]
# 200  "for the discovery and synthesis of quantum dots"  [127]
# 201  "for the discovery and synthesis of quantum dots"  [127]
#
# [202 rows x 6 columns]

# %% [markdown]
# ### a.1) Limpieza de los datos

# %%
Laureates=pd.read_html(LaureatesLink,header=0,flavor='bs4')
Laureates_DF=Laureates[0]

#Eliminando las columnas "Image" y "Ref"
Laureates_DF.drop(columns=["Image","Ref"], inplace=True)

# Renombrando las columnas
Laureates_DF.rename(columns={"Year":"Year_of_award","Laureate[A]":"Laureate","Country[B]":"Country","Rationale[C]":"Rationale"},inplace=True)

#Creando dos nuevas columnas (Birth_year y Death_year a partir de datos preexistentes de la columna Laureate)
Laureates_DF_2=Laureates_DF["Laureate"].str.replace(pat=r'([a-zA-Z]+)',repl='',regex=True) #Reemplazando letras por espacios vacíos
Laureates_DF_2=Laureates_DF_2.str.split("–", expand=True) #crear una columna para cada año

Laureates_DF_2[0]=Laureates_DF_2[0].str.replace(pat=r'(\D)',repl='',regex=True) #Eliminar no dígitos
Laureates_DF_2[1]=Laureates_DF_2[1].str.replace(pat=r'(\D)',repl='',regex=True) #Eliminar no dígitos

Laureates_DF["Birth_year"]=Laureates_DF_2[0]
Laureates_DF["Death_year"]=Laureates_DF_2[1]

#Resultados:
Laureates_DF
# Out:
#      Year_of_award                                  Laureate         Country  \
# 0             1901  Jacobus Henricus van 't Hoff (1852–1911)     Netherlands
# 1             1902          Hermann Emil Fischer (1852–1919)         Germany
# 2             1903       Svante August Arrhenius (1859–1927)          Sweden
# 3             1904            Sir William Ramsay (1852–1916)  United Kingdom
# 4             1905              Adolf von Baeyer (1835–1917)         Germany
# ..             ...                                       ...             ...
# 197           2022                   Morten Meldal (b. 1954)         Denmark
# 198           2022              K. Barry Sharpless (b. 1941)   United States
# 199           2023               Moungi G. Bawendi (b. 1961)   United States
# 200           2023                   Louis E. Brus (b. 1943)   United States
# 201           2023                   Alexey Ekimov (b. 1945)          Russia
#
#                                              Rationale Birth_year Death_year
# 0    "[for his] discovery of the laws of chemical d...       1852       1911
# 1       "[for] his work on sugar and purine syntheses"       1852       1919
# 2      "[for] his electrolytic theory of dissociation"       1859       1927
# 3    "[for his] discovery of the inert gaseous elem...       1852       1916
# 4    "[for] the advancement of organic chemistry an...       1835       1917
# ..                                                 ...        ...        ...
# 197  "for the development of click chemistry and bi...       1954       None
# 198  "for the development of click chemistry and bi...       1941       None
# 199  "for the discovery and synthesis of quantum dots"       1961       None
# 200  "for the discovery and synthesis of quantum dots"       1943       None
# 201  "for the discovery and synthesis of quantum dots"       1945       None
#
# [202 rows x 6 columns]

# %%
# Limpiando la columna "Laureate" para que solo se encuentren los nombres de los ganadores
Laureates_DF["Laureate"]=Laureates_DF["Laureate"].str.replace(pat=r'(\d+)',repl='',regex=True) #eliminar dígitos correspondientes a los años
Laureates_DF["Laureate"]= Laureates_DF["Laureate"].str.replace(pat=' (–)',repl='') #eliminar ' (-)' ó '(b. )' que quedan
Laureates_DF["Laureate"]= Laureates_DF["Laureate"].str.replace(pat='(–)',repl='') #eliminar ' (-)' ó '(b. )' que quedan
Laureates_DF["Laureate"]= Laureates_DF["Laureate"].str.replace(pat=' (b. )',repl='') #eliminar (-) ó (b. ) que quedan
Laureates_DF["Laureate"]= Laureates_DF["Laureate"].str.replace(pat='(b. )',repl='') #eliminar (-) ó (b. ) que quedan

Laureates_DF["Laureate"]= Laureates_DF["Laureate"].str.strip() #eliminar espacios al inicio y al final

#Resultados:
Laureates_DF
# Out:
#      Year_of_award                      Laureate         Country  \
# 0             1901  Jacobus Henricus van 't Hoff     Netherlands
# 1             1902          Hermann Emil Fischer         Germany
# 2             1903       Svante August Arrhenius          Sweden
# 3             1904            Sir William Ramsay  United Kingdom
# 4             1905              Adolf von Baeyer         Germany
# ..             ...                           ...             ...
# 197           2022                 Morten Meldal         Denmark
# 198           2022            K. Barry Sharpless   United States
# 199           2023             Moungi G. Bawendi   United States
# 200           2023                 Louis E. Brus   United States
# 201           2023                 Alexey Ekimov          Russia
#
#                                              Rationale Birth_year Death_year
# 0    "[for his] discovery of the laws of chemical d...       1852       1911
# 1       "[for] his work on sugar and purine syntheses"       1852       1919
# 2      "[for] his electrolytic theory of dissociation"       1859       1927
# 3    "[for his] discovery of the inert gaseous elem...       1852       1916
# 4    "[for] the advancement of organic chemistry an...       1835       1917
# ..                                                 ...        ...        ...
# 197  "for the development of click chemistry and bi...       1954       None
# 198  "for the development of click chemistry and bi...       1941       None
# 199  "for the discovery and synthesis of quantum dots"       1961       None
# 200  "for the discovery and synthesis of quantum dots"       1943       None
# 201  "for the discovery and synthesis of quantum dots"       1945       None
#
# [202 rows x 6 columns]

# %%
#Reemplazando valores "None" en la segunda columna con "Alive"
Laureates_DF['Death_year']=Laureates_DF_2[1].replace({None:'Alive'})

# %%
# Limpiando la columna 'Country'
# Se debe limpiar, porque algunos ganadores presentan más de una nacionalidad
set(Laureates_DF['Country']) # cada país está separado por '\xa0' o doble espacio
# Out:
# {'Argentina',
#  'Australia \xa0United Kingdom',
#  'Austria \xa0Kingdom of Yugoslavia',
#  'Belgium',
#  'Canada',
#  'Canada \xa0Hungary',
#  'Canada \xa0United States',
#  'Canada \xa0West Germany',
#  'Czechoslovakia',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Germany \xa0Hungary',
#  'Germany \xa0Romania[117]',
#  'Germany \xa0United States[121]',
#  'Hungary',
#  'Israel',
#  'Israel \xa0United States',
#  'Italy',
#  'Japan',
#  'Japan[108]',
#  'Kingdom of Yugoslavia  Switzerland',
#  'Mexico',
#  'Netherlands',
#  'Norway',
#  'Not awarded',
#  'Poland (\xa0Russian Empire) \xa0France',
#  'Russia',
#  'Soviet Union',
#  'Sweden',
#  'Sweden \xa0Germany',
#  'Sweden \xa0United Kingdom',
#  'Switzerland',
#  'United Kingdom',
#  'United Kingdom \xa0New Zealand',
#  'United Kingdom \xa0United States',
#  'United States',
#  'United States \xa0Austria',
#  'United States \xa0Canada',
#  'United States \xa0Egypt',
#  'United States \xa0Hungary',
#  'United States \xa0India \xa0United Kingdom',
#  'United States \xa0Israel',
#  'United States \xa0New Zealand',
#  'United States \xa0Norway',
#  'United States \xa0Poland',
#  'United States \xa0Republic of China',
#  'United States \xa0Turkey',
#  'United States \xa0United Kingdom \xa0Israel[115]',
#  'West Germany',
#  'Yugoslavia  Switzerland'}

# %%
# Solo se mantendrá el primer país, porque corresponde al país de nacimiento
a = Laureates_DF['Country'].str.split("\xa0",expand=True) #separar por '\xa0'
a = a[0].str.split("  ",expand=True) #separar por doble espacio
a = a[0].str.split("[",expand=True) #para eliminar las referencias que se encuentran como números entre corchetes
a = a[0].str.split("(",expand=True)
a[0] = a[0].str.strip() #eliminar espacios al inicio y al final

Laureates_DF['Country_of_birth']=a[0]

#resultado:
set(Laureates_DF['Country_of_birth'])
# Out:
# {'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Canada',
#  'Czechoslovakia',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Hungary',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kingdom of Yugoslavia',
#  'Mexico',
#  'Netherlands',
#  'Norway',
#  'Not awarded',
#  'Poland',
#  'Russia',
#  'Soviet Union',
#  'Sweden',
#  'Switzerland',
#  'United Kingdom',
#  'United States',
#  'West Germany',
#  'Yugoslavia'}

# %%
#Dataframe resultante
Laureates_DF=Laureates_DF.drop(columns={'Country':'Country_of_birth'})
Laureates_DF
# Out:
#      Year_of_award                      Laureate  \
# 0             1901  Jacobus Henricus van 't Hoff
# 1             1902          Hermann Emil Fischer
# 2             1903       Svante August Arrhenius
# 3             1904            Sir William Ramsay
# 4             1905              Adolf von Baeyer
# ..             ...                           ...
# 197           2022                 Morten Meldal
# 198           2022            K. Barry Sharpless
# 199           2023             Moungi G. Bawendi
# 200           2023                 Louis E. Brus
# 201           2023                 Alexey Ekimov
#
#                                              Rationale Birth_year Death_year  \
# 0    "[for his] discovery of the laws of chemical d...       1852       1911
# 1       "[for] his work on sugar and purine syntheses"       1852       1919
# 2      "[for] his electrolytic theory of dissociation"       1859       1927
# 3    "[for his] discovery of the inert gaseous elem...       1852       1916
# 4    "[for] the advancement of organic chemistry an...       1835       1917
# ..                                                 ...        ...        ...
# 197  "for the development of click chemistry and bi...       1954      Alive
# 198  "for the development of click chemistry and bi...       1941      Alive
# 199  "for the discovery and synthesis of quantum dots"       1961      Alive
# 200  "for the discovery and synthesis of quantum dots"       1943      Alive
# 201  "for the discovery and synthesis of quantum dots"       1945      Alive
#
#     Country_of_birth
# 0        Netherlands
# 1            Germany
# 2             Sweden
# 3     United Kingdom
# 4            Germany
# ..               ...
# 197          Denmark
# 198    United States
# 199    United States
# 200    United States
# 201           Russia
#
# [202 rows x 6 columns]

# %% [markdown]
# ## b) Fuente 2: "Nominees"

# %%
import pandas as pd

NomineesLink="https://en.wikipedia.org/wiki/List_of_nominees_for_the_Nobel_Prize_in_Chemistry"
Nominees=pd.read_html(NomineesLink,header=0,flavor='bs4')
type(Nominees)
# Out:
# list

# %%
range(len(Nominees))
# Out:
# range(0, 15)

# %%
#El primer elemento de la lista es un DF que contiene adjuntos verticalmente datos de los nominados de 1901 a 1909
Nominees[0]
# Out:
#     Picture                          Name  \
# 0    1901.0                          1901
# 1       NaN  Jacobus Henricus van 't Hoff
# 2       NaN                  Emil Fischer
# 3       NaN              Svante Arrhenius
# 4       NaN                 Henri Moissan
# 5       NaN            Zdenko Hans Skraup
# 6       NaN           Marcellin Berthelot
# 7       NaN          William Jackson Pope
# 8    1902.0                          1902
# 9       NaN                William Ramsay
# 10      NaN              Adolf von Baeyer
# 11      NaN     Theodore William Richards
# 12      NaN               Rudolf Knietsch
# 13      NaN           Johannes Wislicenus
# 14      NaN          Oliver Wolcott Gibbs
# 15      NaN        Edward Williams Morley
# 16      NaN                Armand Gautier
# 17   1903.0                          1903
# 18      NaN         Harmon Northrop Morse
# 19   1904.0                          1904
# 20      NaN               Wilhelm Ostwald
# 21   1905.0                          1905
# 22      NaN                Eduard Buchner
# 23      NaN              Dmitri Mendeleev
# 24      NaN             Giacomo Ciamician
# 25      NaN      Henry Louis Le Chatelier
# 26   1906.0                          1906
# 27      NaN                Walther Nernst
# 28      NaN               Victor Grignard
# 29   1907.0                          1907
# 30      NaN                 Paul Sabatier
# 31      NaN             Ernest Rutherford
# 32      NaN                  Otto Wallach
# 33      NaN                 Alfred Werner
# 34      NaN         Fredrik Adolf Kjellin
# 35      NaN          Stanislao Cannizzaro
# 36      NaN         Sophus Mads Jørgensen
# 37      NaN               William Crookes
# 38      NaN                 Heinrich Caro
# 39      NaN                  Adolph Frank
# 40      NaN                   Samuel Eyde
# 41      NaN            Kristian Birkeland
# 42      NaN               Theodor Curtius
# 43      NaN                  Albin Haller
# 44   1908.0                          1908
# 45      NaN           Richard Willstätter
# 46      NaN               Frederick Soddy
# 47      NaN               Albrecht Kossel
# 48      NaN               Gustaf de Laval
# 49      NaN                   Georg Lunge
# 50      NaN        Arthur Rudolf Hantzsch
# 51   1909.0                          1909
# 52      NaN     Edmund Oscar von Lippmann
# 53      NaN         Hans Heinrich Landolt
# 54      NaN                Otto Schönherr
# 55      NaN                   Karl Engler
# 56      NaN       Jean-Baptiste Senderens
# 57      NaN              Gabriel Bertrand
#
#                                                  Born  \
# 0                                                1901
# 1              August 30, 1852 Rotterdam, Netherlands
# 2                 October 9, 1852 Euskirchen, Germany
# 3                   February 19, 1859 Uppsala, Sweden
# 4                    September 28, 1852 Paris, France
# 5                March 3, 1850 Prague, Czech Republic
# 6                      October 25, 1827 Paris, France
# 7                      March 31, 1870 London, England
# 8                                                1902
# 9                   October 2, 1852 Glasgow, Scotland
# 10                   October 31, 1835 Berlin, Germany
# 11  January 31, 1868 Germantown, Philadelphia, Uni...
# 12                    December 13, 1854 Opole, Poland
# 13                    June 24, 1835 Querfurt, Germany
# 14     February 21, 1822 New York City, United States
# 15  January 29, 1838 Newark, New Jersey, United St...
# 16                September 23, 1837 Narbonne, France
# 17                                               1903
# 18  October 15, 1848 Cambridge, Vermont, United St...
# 19                                               1904
# 20                     September 2, 1853 Riga, Latvia
# 21                                               1905
# 22                       May 20, 1860 Munich, Germany
# 23                   February 8, 1834 Tobolsk, Russia
# 24                     August 27, 1857 Trieste, Italy
# 25                      October 8, 1850 Paris, France
# 26                                               1906
# 27              June 25, 1864 Gmina Wąbrzeźno, Poland
# 28          May 6, 1871 Cherbourg-en-Cotentin, France
# 29                                               1907
# 30               November 5, 1854 Carcassonne, France
# 31           August 30, 1871 Brightwater, New Zealand
# 32                 March 27, 1847 Königsberg, Prussia
# 33                 December 12, 1866 Mulhouse, France
# 34                  April 24, 1872 Södertälje, Sweden
# 35                       July 13, 1826 Palermo, Italy
# 36                     July 4, 1837 Slagelse, Denmark
# 37                      June 17, 1832 London, England
# 38                   February 13, 1834 Poznań, Poland
# 39                   January 20, 1834 Klötze, Germany
# 40                   October 29, 1866 Arendal, Norway
# 41                     December 13, 1867 Oslo, Norway
# 42                     May 27, 1857 Duisburg, Germany
# 43                    March 7, 1849 Fellering, France
# 44                                               1908
# 45                 August 13, 1872 Karlsruhe, Germany
# 46              September 2, 1877 Eastbourne, England
# 47                September 16, 1853 Rostock, Germany
# 48                           May 9, 1845 Orsa, Sweden
# 49                 September 15, 1839 Wrocław, Poland
# 50                     March 7, 1857 Dresden, Germany
# 51                                               1909
# 52                    January 9, 1857 Vienna, Austria
# 53               December 5, 1831 Zürich, Switzerland
# 54                 December 1, 1861 Chemnitz, Germany
# 55                  January 5, 1842 Weisweil, Germany
# 56                 January 27, 1856 Barbachen, France
# 57                         May 17, 1867 Paris, France
#
#                                                  Died  \
# 0                                                1901
# 1                       March 1, 1911 Berlin, Germany
# 2                       July 15, 1919 Berlin, Germany
# 3                   October 2, 1927 Stockholm, Sweden
# 4                     February 20, 1907 Paris, France
# 5                  September 10, 1910 Vienna, Austria
# 6                        March 18, 1907 Paris, France
# 7                 October 17, 1939 Cambridge, England
# 8                                                1902
# 9                 July 23, 1916 High Wycombe, England
# 10                 August 20, 1917 Starnberg, Germany
# 11  April 2, 1928 Cambridge,_Massachusetts, United...
# 12                 May 28, 1906 Ludwigshafen, Germany
# 13                  December 5, 1902 Leipzig, Germany
# 14  December 9, 1908 Portsmouth, Rhode Island, Uni...
# 15  February 24, 1923 West Hartford, Connecticut, ...
# 16                       July 27, 1920 Cannes, France
# 17                                               1903
# 18  September 8, 1920 Chebeague Island, Maine, Uni...
# 19                                               1904
# 20                      April 4, 1932 Grimma, Germany
# 21                                               1905
# 22                   August 13, 1917 Focșani, Romania
# 23          February 2, 1907 Saint Petersburg, Russia
# 24                     January 2, 1922 Bologna, Italy
# 25    September 17, 1936 Miribel-les-Échelles, France
# 26                                               1906
# 27                   November 18, 1941 Niwica, Poland
# 28                     December 13, 1935 Lyon, France
# 29                                               1907
# 30                   August 14, 1914 Toulouse, France
# 31                October 19, 1937 Cambridge, England
# 32               February 26, 1931 Göttingen, Germany
# 33              November 15, 1919 Zürich, Switzerland
# 34                December 30, 1910 Stockholm, Sweden
# 35                           May 10, 1910 Rome, Italy
# 36                  April 1, 1914 Copenhagen, Denmark
# 37                      April 4, 1919 London, England
# 38                September 11, 1910 Dresden, Germany
# 39                       May 30, 1916 Berlin, Germany
# 40                 June 21, 1940 Åsgårdstrand, Norway
# 41                      June 15, 1917 Kanagawa, Japan
# 42               February 8, 1928 Heidelberg, Germany
# 43                       April 29, 1925 Paris, France
# 44                                               1908
# 45                August 3, 1942 Muralto, Switzerland
# 46               September 22, 1956 Brighton, England
# 47                   July 5, 1927 Heidelberg, Germany
# 48                 February 2, 1913 Stockholm, Sweden
# 49                January 3, 1923 Zürich, Switzerland
# 50                    March 14, 1935 Dresden, Germany
# 51                                               1909
# 52          September 24, 1940 Halle (Saale), Germany
# 53                     March 15, 1910 Berlin, Germany
# 54                 December 25, 1926 Dresden, Germany
# 55                February 7, 1925 Karlsruhe, Germany
# 56               September 26, 1937 Barbachen, France
# 57                        June 10, 1962 Paris, France
#
#                                       Years Nominated  \
# 0                                                1901
# 1                                                1901
# 2                              1901, 1902, 1916, 1919
# 3                                    1901, 1902, 1903
# 4                  1901, 1902, 1903, 1904, 1905, 1906
# 5                                                1901
# 6                  1901, 1902, 1903, 1904, 1906, 1907
# 7                                    1901, 1907, 1927
# 8                                                1902
# 9                                    1902, 1903, 1904
# 10                             1902, 1903, 1904, 1905
# 11  1902, 1905, 1908, 1909, 1910, 1911, 1912, 1913...
# 12                                               1902
# 13                                               1902
# 14                                               1902
# 15                                   1902, 1908, 1910
# 16                                         1902, 1916
# 17                                               1903
# 18                                         1903, 1910
# 19                                               1904
# 20                 1904, 1905, 1906, 1907, 1908, 1909
# 21                                               1905
# 22                                         1905, 1907
# 23                                   1905, 1906, 1907
# 24  1905, 1907, 1908, 1911, 1912, 1914, 1916, 1919...
# 25  1905, 1907, 1908, 1909, 1914, 1915, 1920, 1921...
# 26                                               1906
# 27  1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913...
# 28                       1906, 1909, 1910, 1912, 1928
# 29                                               1907
# 30                 1907, 1909, 1911, 1912, 1928, 1929
# 31                                         1907, 1908
# 32                                   1907, 1908, 1910
# 33                       1907, 1908, 1911, 1912, 1913
# 34                                               1907
# 35                                               1907
# 36                                               1907
# 37                             1907, 1908, 1909, 1910
# 38                                         1907, 1910
# 39                                   1907, 1910, 1916
# 40                                   1907, 1909, 1913
# 41                             1907, 1909, 1912, 1913
# 42  1907, 1908, 1909, 1910, 1913, 1914, 1916, 1917...
# 43  1907, 1912, 1916, 1919, 1920, 1921, 1922, 1923...
# 44                                               1908
# 45           1908, 1909, 1911, 1912, 1913, 1914, 1915
# 46                             1908, 1918, 1919, 1922
# 47                                               1908
# 48                                               1908
# 49                                               1908
# 50                                         1908, 1927
# 51                                               1909
# 52                                               1909
# 53                                         1909, 1910
# 54                                         1909, 1912
# 55                             1909, 1910, 1911, 1916
# 56                                   1909, 1928, 1929
# 57  1909, 1928, 1929, 1931, 1932, 1933, 1934, 1935...
#
#                                                 Notes
# 0                                                1901
# 1           Won the 1901 Nobel Prize in Chemistry.[4]
# 2   Won the 1902 Nobel Prize in Chemistry,[5] late...
# 3   Won the 1903 Nobel Prize in Chemistry and nomi...
# 4           Won the 1906 Nobel Prize in Chemistry.[8]
# 5   Nominated the only time by Eduard Lippmann (18...
# 6                                                [10]
# 7                                                [11]
# 8                                                1902
# 9   Won the 1904 Nobel Prize in Chemistry and nomi...
# 10         Won the 1905 Nobel Prize in Chemistry.[13]
# 11  Won the 1914 Nobel Prize in Chemistry in 1915....
# 12           Nominated the only time by P.Klason.[15]
# 13  Nominated the only time by Zd.H.Skraup.[16] Di...
# 14      Nominated the only time by Ch.Edw.Munroe.[17]
# 15                                               [18]
# 16  Nominated for Nobel Prize in Physiology or Med...
# 17                                               1903
# 18  Nominated by Harry Clary Jones (1865–1916) fro...
# 19                                               1904
# 20         Won the 1909 Nobel Prize in Chemistry.[22]
# 21                                               1905
# 22  Won the 1907 Nobel Prize in Chemistry and nomi...
# 23                                               [24]
# 24                                               [25]
# 25  Nominated for the Nobel Prize in Physics too.[26]
# 26                                               1906
# 27  Won the 1920 Nobel Prize in Chemistry in 1921 ...
# 28         Won the 1912 Nobel Prize in Chemistry.[28]
# 29                                               1907
# 30         Won the 1912 Nobel Prize in Chemistry.[29]
# 31  Won the 1908 Nobel Prize in Chemistry and nomi...
# 32         Won the 1910 Nobel Prize in Chemistry.[31]
# 33         Won the 1913 Nobel Prize in Chemistry.[32]
# 34    Nominated the only time by Otto Pettersson.[33]
# 35                                               [34]
# 36                                               [35]
# 37  Nominated for the Nobel Prize in Physics too.[36]
# 38          Nominated jointly with Ad.Frank only.[37]
# 39                                               [38]
# 40      Nominated jointly with Kr.Birkeland only.[39]
# 41  Nominated for the Nobel Prize in Physics too.[40]
# 42                                               [41]
# 43                                               [42]
# 44                                               1908
# 45         Won the 1915 Nobel Prize in Chemistry.[43]
# 46  Won the 1921 Nobel Prize in Chemistry in 1922....
# 47  Won the 1910 Nobel Prize in Physiology or Medi...
# 48  Nominated the only time by Otto Pettersson and...
# 49                                               [47]
# 50                                               [48]
# 51                                               1909
# 52  Nominated the only time by Alexander Herzfeld ...
# 53                                               [50]
# 54                                               [51]
# 55                                               [52]
# 56        Nominated jointly with P.Sabatier only.[53]
# 57  Nominated for Nobel Prize in Physiology or Med...

# %% [markdown]
# ### b.1) Filtrado y concatenación de la data

# %%
# Función cotas: permite encontrar el intervalo de filas donde se encuentran los nominados por cada año
# Por ejemplo, los que fueron nominados en 1901, se encuentran en las filas 1:7 del elemento 1 de la lista Nominees

def cotas(x,y):
    try:
        cota_inf=Nominees[x].index.get_loc(Nominees[x][Nominees[x]['Picture'] == y].index[0])
        cota_sup= Nominees[x].index.get_loc(Nominees[x][Nominees[x]['Picture'] == y+1].index[0])
        return range(cota_inf+1,cota_sup)
    except:
        cota_inf=Nominees[x].index.get_loc(Nominees[x][Nominees[x]['Picture'] == y].index[0])
        cota_sup= Nominees[x].shape[0]
        return range(cota_inf+1,cota_sup)
    

list(cotas(0,1901))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Con la función **cotas(x,y)**, se busca encontrar el intervalo de filas donde se encuentran los nominados por cada año. Con esto, acotar los DFs asociados a cada año, en función a dicho intervalo de filas.
# Parámetros:
# - y: año de nominación
# - x: índice de la lista Nominees. x admite un valor de 0,1,2,3,4,5,6 ó 7, dependiendo del Dataframe, donde se encuentre el año de nominación deseado.
#
# Se tiene información de los nominados desde 1901 hasta 1970 en forma de 8 DFS:
# - 1901–1909: Nominees[0], x=0
# - 1910–1919: Nominees[1], x=1
# - 1920–1929: Nominees[2], x=2
# - 1930–1939: Nominees[3], x=3
# - 1940–1949: Nominees[4], x=4
# - 1950–1959: Nominees[5], x=5
# - 1960–1969: Nominees[6], x=6
# - 1970: Nominees[7], x=7

# %%
#DFs de 1901-1909
NomineesDFs_1901_1909=[Nominees[0].iloc[cotas(0,i),:] for i in list(range(1901,1910))]

# DFs de 1910 a 1969
    #Forma larga:
NomineesDFs_1910_1919=[Nominees[1].iloc[cotas(1,i),:] for i in list(range(1910,1920))]
NomineesDFs_1920_1929=[Nominees[2].iloc[cotas(2,i),:] for i in list(range(1920,1930))]
NomineesDFs_1930_1939=[Nominees[3].iloc[cotas(3,i),:] for i in list(range(1930,1940))]
NomineesDFs_1940_1949=[Nominees[4].iloc[cotas(4,i),:] for i in list(range(1940,1950))]
NomineesDFs_1950_1959=[Nominees[5].iloc[cotas(5,i),:] for i in list(range(1950,1960))]
NomineesDFs_1960_1969=[Nominees[6].iloc[cotas(6,i),:] for i in list(range(1960,1970))]
    #Forma simplificada: 
NomineesDFs_1910_1969=[Nominees[j].iloc[cotas(j,i),:] for j in list(range(1,7)) for i in list(range(1900+j*10,1910+j*10))]


#DF de 1970 
#Los datos Nominees[7].Picture no se encontraban como números reales (float)
#Por esto, se tuvo que realizar la conversión respectiva
Nominees[7].Picture=pd.to_numeric(Nominees[7].Picture,errors='coerce')
NomineesDF_1970=Nominees[7].iloc[cotas(7,1970),:]

# %%
#Concatenando los DFs de cada lista
Nominees=pd.read_html(NomineesLink,header=0,flavor='bs4')
NomineesDFs_1901_1909=[Nominees[0].iloc[cotas(0,i),:] for i in list(range(1901,1910))]
NomineesDFs_1901_1909=pd.concat(NomineesDFs_1901_1909[i] for i in range(len(NomineesDFs_1901_1909))) 

NomineesDFs_1910_1969=[Nominees[j].iloc[cotas(j,i),:] for j in list(range(1,7)) for i in list(range(1900+j*10,1910+j*10))]
NomineesDFs_1910_1969=pd.concat(NomineesDFs_1910_1969[i] for i in range(len(NomineesDFs_1910_1969))) 

Nominees[7].Picture=pd.to_numeric(Nominees[7].Picture,errors='coerce')
NomineesDF_1970=Nominees[7].iloc[cotas(7,1970),:]

NomineesList=[NomineesDFs_1901_1909,NomineesDFs_1910_1969,NomineesDF_1970]
NomineesAllDFs=pd.concat(NomineesList)

#Resultado
NomineesAllDFs
# Out:
#     Picture                          Name  \
# 1       NaN  Jacobus Henricus van 't Hoff
# 2       NaN                  Emil Fischer
# 3       NaN              Svante Arrhenius
# 4       NaN                 Henri Moissan
# 5       NaN            Zdenko Hans Skraup
# ..      ...                           ...
# 26      NaN    Charles Gilbert Overberger
# 27      NaN   Henry Montague (Monty) Frey
# 28      NaN           Jack Sylvester Hine
# 29      NaN               Wolfgang Kirmse
# 30      NaN                  Tetsuo Nozoe
#
#                                                  Born  \
# 1              August 30, 1852 Rotterdam, Netherlands
# 2                 October 9, 1852 Euskirchen, Germany
# 3                   February 19, 1859 Uppsala, Sweden
# 4                    September 28, 1852 Paris, France
# 5                March 3, 1850 Prague, Czech Republic
# ..                                                ...
# 26  October 12, 1920 Barnesboro, Pennsylvania, Uni...
# 27                  February 27, 1929 London, England
# 28  July 2, 1923  Coronado, California, United States
# 29          June 26, 1930  Frankfurt am Main, Germany
# 30                        May 16, 1902  Sendai, Japan
#
#                                            Died  \
# 1                 March 1, 1911 Berlin, Germany
# 2                 July 15, 1919 Berlin, Germany
# 3             October 2, 1927 Stockholm, Sweden
# 4               February 20, 1907 Paris, France
# 5            September 10, 1910 Vienna, Austria
# ..                                          ...
# 26     March 17, 1997  Ann Arbor, United States
# 27                                          NaN
# 28  July 6, 1988  Columbus, Ohio, United States
# 29                                          NaN
# 30                  April 4, 1996  Tokyo, Japan
#
#                        Years Nominated  \
# 1                                 1901
# 2               1901, 1902, 1916, 1919
# 3                     1901, 1902, 1903
# 4   1901, 1902, 1903, 1904, 1905, 1906
# 5                                 1901
# ..                                 ...
# 26                                1970
# 27                                1970
# 28                                1970
# 29                                1970
# 30                     1970, 1974[747]
#
#                                                 Notes Unnamed: 6
# 1           Won the 1901 Nobel Prize in Chemistry.[4]        NaN
# 2   Won the 1902 Nobel Prize in Chemistry,[5] late...        NaN
# 3   Won the 1903 Nobel Prize in Chemistry and nomi...        NaN
# 4           Won the 1906 Nobel Prize in Chemistry.[8]        NaN
# 5   Nominated the only time by Eduard Lippmann (18...        NaN
# ..                                                ...        ...
# 26  Jointly nominated with K.J.Freudenberg and Al....        NaN
# 27  Jointly nominated the only time by Youssef Isk...        NaN
# 28  Jointly nominated the only time by Youssef Isk...        NaN
# 29  Jointly nominated the only time by Youssef Isk...        NaN
# 30                                              [748]        NaN
#
# [640 rows x 7 columns]

# %% [markdown]
# ### b.2) Limpieza del DataFrame resultante de la concatenación

# %%
NomineesAllDFs=pd.concat(NomineesList)

# Manteniendo solo el país en los valores de la columna Born
a=NomineesAllDFs['Born'].str.split(',',expand=True)
a[2]=a[2].str.replace(pat=r'\d|\s|\W',repl="",regex=True) #country
NomineesAllDFs["Country"]=a[2]

#Eliminando y renombrando columnas
NomineesAllDFs=NomineesAllDFs.drop(columns=['Picture','Notes','Unnamed: 6','Born','Died'])
NomineesAllDFs=NomineesAllDFs.rename(columns={'Name':'Nominee','Years Nominated':'Years_Nominated'})

NomineesAllDFs
# Out:
#                          Nominee                     Years_Nominated  \
# 1   Jacobus Henricus van 't Hoff                                1901
# 2                   Emil Fischer              1901, 1902, 1916, 1919
# 3               Svante Arrhenius                    1901, 1902, 1903
# 4                  Henri Moissan  1901, 1902, 1903, 1904, 1905, 1906
# 5             Zdenko Hans Skraup                                1901
# ..                           ...                                 ...
# 26    Charles Gilbert Overberger                                1970
# 27   Henry Montague (Monty) Frey                                1970
# 28           Jack Sylvester Hine                                1970
# 29               Wolfgang Kirmse                                1970
# 30                  Tetsuo Nozoe                     1970, 1974[747]
#
#           Country
# 1     Netherlands
# 2         Germany
# 3          Sweden
# 4          France
# 5   CzechRepublic
# ..            ...
# 26   Pennsylvania
# 27        England
# 28     California
# 29        Germany
# 30          Japan
#
# [640 rows x 3 columns]

# %%
#Limpieza de la columna años de nominación

#Eliminar espacios
NomineesAllDFs['Years_Nominated']=NomineesAllDFs['Years_Nominated'].str.replace(pat=r'\s',repl="",regex=True)

#Eliminar números separados por "[", porque aluden a referencias. Ejm: [747] se refiere a la referencia 747 de la fuente 2
NomineesAllDFs['Years_Nominated']=NomineesAllDFs['Years_Nominated'].str.split("[",expand=True)[0]

NomineesAllDFs
# Out:
#                          Nominee                Years_Nominated        Country
# 1   Jacobus Henricus van 't Hoff                           1901    Netherlands
# 2                   Emil Fischer            1901,1902,1916,1919        Germany
# 3               Svante Arrhenius                 1901,1902,1903         Sweden
# 4                  Henri Moissan  1901,1902,1903,1904,1905,1906         France
# 5             Zdenko Hans Skraup                           1901  CzechRepublic
# ..                           ...                            ...            ...
# 26    Charles Gilbert Overberger                           1970   Pennsylvania
# 27   Henry Montague (Monty) Frey                           1970        England
# 28           Jack Sylvester Hine                           1970     California
# 29               Wolfgang Kirmse                           1970        Germany
# 30                  Tetsuo Nozoe                      1970,1974          Japan
#
# [640 rows x 3 columns]

# %%
#Ordenando el DF por año (una fila para cada año de nominación. Ejm: 1901,1902 -> 2 filas )
NomineesAllDFs_Long=NomineesAllDFs.copy()

#se separa en una fila distinta cada elemento de la columna 'Years_Nominated' separado de otro por comas
NomineesAllDFs_Long['Years_Nominated']=NomineesAllDFs_Long['Years_Nominated'].str.split(",") 
NomineesAllDFs_Long=NomineesAllDFs_Long.explode('Years_Nominated')
NomineesAllDFs_Long.reset_index(drop=True,inplace=True)
NomineesAllDFs_Long
# Out:
#                            Nominee Years_Nominated      Country
# 0     Jacobus Henricus van 't Hoff            1901  Netherlands
# 1                     Emil Fischer            1901      Germany
# 2                     Emil Fischer            1902      Germany
# 3                     Emil Fischer            1916      Germany
# 4                     Emil Fischer            1919      Germany
# ...                            ...             ...          ...
# 2028   Henry Montague (Monty) Frey            1970      England
# 2029           Jack Sylvester Hine            1970   California
# 2030               Wolfgang Kirmse            1970      Germany
# 2031                  Tetsuo Nozoe            1970        Japan
# 2032                  Tetsuo Nozoe            1974        Japan
#
# [2033 rows x 3 columns]

# %%
#Transformación de la tabla a horizontal
NomineesAllDFs_Wide=pd.pivot_table(NomineesAllDFs_Long,
               values=["Nominee"], # values to use
               index=['Country'], # unit of analysis
               columns=['Years_Nominated'], # the values for NEW column
                aggfunc=lambda x: ' '.join(str(v) for v in x))

NomineesAllDFs_Wide
# Out:
#                       Nominee                                               \
# Years_Nominated           152  153 1901 1902 1903 1904 1905 1906 1907 1908
# Country
# Argentina                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Armenia                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Australia                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Austria                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Belarus                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# WestRidingofYorkshire     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Wiltshire                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Wisconsin                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nowPoland                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# nowUkraine                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                        ...                                        \
# Years_Nominated        ...                                  1962
# Country                ...
# Argentina              ...                                   NaN
# Armenia                ...                                   NaN
# Australia              ...                                   NaN
# Austria                ...  Max Perutz Fritz Feigl Carl Djerassi
# Belarus                ...                                   NaN
# ...                    ...                                   ...
# WestRidingofYorkshire  ...                                   NaN
# Wiltshire              ...                                   NaN
# Wisconsin              ...                                   NaN
# nowPoland              ...                                   NaN
# nowUkraine             ...                                   NaN
#
#                                                               \
# Years_Nominated                          1963           1964
# Country
# Argentina                                 NaN            NaN
# Armenia                                   NaN            NaN
# Australia                                 NaN            NaN
# Austria                Max Perutz Fritz Feigl  Carl Djerassi
# Belarus                                   NaN            NaN
# ...                                       ...            ...
# WestRidingofYorkshire                     NaN            NaN
# Wiltshire                                 NaN            NaN
# Wisconsin                                 NaN            NaN
# nowPoland                        Fritz London            NaN
# nowUkraine                                NaN            NaN
#
#                                                                       \
# Years_Nominated                                                 1965
# Country
# Argentina                                                        NaN
# Armenia                                            Oganes K. Davtyan
# Australia                                  John Warcup Cornforth Jr.
# Austria                Herman Francis Mark Carl Djerassi Otto Kratky
# Belarus                                                          NaN
# ...                                                              ...
# WestRidingofYorkshire                                            NaN
# Wiltshire                                                        NaN
# Wisconsin                                      James Elliot Carnahan
# nowPoland                                                        NaN
# nowUkraine                                            Erwin Chargaff
#
#                                                   \
# Years_Nominated                             1966
# Country
# Argentina                                    NaN
# Armenia                                      NaN
# Australia              John Warcup Cornforth Jr.
# Austria                Fritz Feigl Carl Djerassi
# Belarus                                      NaN
# ...                                          ...
# WestRidingofYorkshire                        NaN
# Wiltshire                                    NaN
# Wisconsin                                    NaN
# nowPoland                                    NaN
# nowUkraine                       Bernard Halpern
#
#                                                                     \
# Years_Nominated                                               1967
# Country
# Argentina                                                      NaN
# Armenia                                                        NaN
# Australia                                John Warcup Cornforth Jr.
# Austria                Fritz Feigl Herman Francis Mark Otto Kratky
# Belarus                                                        NaN
# ...                                                            ...
# WestRidingofYorkshire                           Geoffrey Wilkinson
# Wiltshire                                 Frederick Robert Whatley
# Wisconsin                                                      NaN
# nowPoland                                Max Rudolf "Rudi" Lemberg
# nowUkraine                                          Erwin Chargaff
#
#                                                                           \
# Years_Nominated                                                     1968
# Country
# Argentina                                                            NaN
# Armenia                                                              NaN
# Australia                                      John Warcup Cornforth Jr.
# Austria                Herman Francis Mark Carl Djerassi Otto Kratky ...
# Belarus                                       Yakov Borisovich Zeldovich
# ...                                                                  ...
# WestRidingofYorkshire                                 Geoffrey Wilkinson
# Wiltshire                                                            NaN
# Wisconsin                                                            NaN
# nowPoland                                                            NaN
# nowUkraine                                                           NaN
#
#                                                                           \
# Years_Nominated                                                     1969
# Country
# Argentina                                                            NaN
# Armenia                                                              NaN
# Australia                       John Warcup Cornforth Jr. Rowland Pettit
# Austria                Herman Francis Mark Carl Djerassi Otto Kratky ...
# Belarus                                                              NaN
# ...                                                                  ...
# WestRidingofYorkshire                                 Geoffrey Wilkinson
# Wiltshire                                                            NaN
# Wisconsin                                                            NaN
# nowPoland                      Konstantin Antonovich Petrzhak (Pietrzak)
# nowUkraine                                             David Nachmansohn
#
#
# Years_Nominated                                                   1970 1974
# Country
# Argentina                                                          NaN  NaN
# Armenia                                                            NaN  NaN
# Australia                                    John Warcup Cornforth Jr.  NaN
# Austria                Herman Francis Mark Carl Djerassi Klaus Biemann  NaN
# Belarus                                                            NaN  NaN
# ...                                                                ...  ...
# WestRidingofYorkshire                               Geoffrey Wilkinson  NaN
# Wiltshire                                                          NaN  NaN
# Wisconsin                                                          NaN  NaN
# nowPoland                                                          NaN  NaN
# nowUkraine                                                         NaN  NaN
#
# [99 rows x 73 columns]

# %% [markdown]
# **Problema**: Los años 152, 153 y 1974* deben ser corregidos.
# *Nota: la lista oficial de candidatos al nobel aparece 50 años luego de la fecha de nominación, por lo que aún no se han pubiclado los nominados en 1974

# %%
# Identificación de las filas de nominados, donde hay error en los años
NomineesAllDFs_Long.loc[NomineesAllDFs_Long['Years_Nominated']=='152'] #Resultado: Jaroslav Heyrovský
NomineesAllDFs_Long.loc[NomineesAllDFs_Long['Years_Nominated']=='153'] #Resultado: Jaroslav Heyrovský
NomineesAllDFs_Long.loc[NomineesAllDFs_Long['Years_Nominated']=='1974'] #Resultado: Tetsuo Nozoe
# Out:
#            Nominee Years_Nominated Country
# 2032  Tetsuo Nozoe            1974   Japan

# %% [markdown]
# **Observaciones**: Según [la página de los premios Nobel](https://www.nobelprize.org/prizes/chemistry/1959/heyrovsky/nominations/), Jaroslav Heyrovský fue nominado en 1934,1938,1940,1944,1947,1950,**1952,1953**,1954,1955,1956,1957,1958,1959. Por tanto, fue un error de tipeo de la [fuente 2](https://en.wikipedia.org/wiki/List_of_nominees_for_the_Nobel_Prize_in_Chemistry). Del mismo modo, solo se reporta que Tetsuo Nozoe fue nominado en 1970 y no en 1974.

# %%
# Corrección de los datos
NomineesAllDFs.loc[NomineesAllDFs['Nominee']=='Jaroslav Heyrovský'] #row: 27
NomineesAllDFs.loc[27,'Years_Nominated']='1934,1938,1940,1944,1947,1950,1952,1953,1954,1955,1956,1957,1958,1959'

# Corrección de los datos
NomineesAllDFs.loc[NomineesAllDFs['Nominee']=='Tetsuo Nozoe'] #row: 30
NomineesAllDFs.loc[30,'Years_Nominated']='1970'

#Ordenando el DF por año (una fila para cada año de nominación)
NomineesAllDFs_Long=NomineesAllDFs.copy()
NomineesAllDFs_Long['Years_Nominated']=NomineesAllDFs_Long['Years_Nominated'].str.split(",")
NomineesAllDFs_Long=NomineesAllDFs_Long.explode('Years_Nominated')
NomineesAllDFs_Long.reset_index(drop=True,inplace=True)

#DF resultante
NomineesAllDFs_Long
# Out:
#                            Nominee Years_Nominated      Country
# 0     Jacobus Henricus van 't Hoff            1901  Netherlands
# 1                     Emil Fischer            1901      Germany
# 2                     Emil Fischer            1902      Germany
# 3                     Emil Fischer            1916      Germany
# 4                     Emil Fischer            1919      Germany
# ...                            ...             ...          ...
# 2034   Henry Montague (Monty) Frey            1958      England
# 2035   Henry Montague (Monty) Frey            1959      England
# 2036           Jack Sylvester Hine            1970   California
# 2037               Wolfgang Kirmse            1970      Germany
# 2038                  Tetsuo Nozoe            1970        Japan
#
# [2039 rows x 3 columns]

# %%
# Para realizar merge con las otras dos fuentes, se agruparán los nominados por año
# Por esto, solo se conservarán las columnas 'Years_Nominated' y 'Nominees'

Nominees_DF_2=NomineesAllDFs_Long.groupby(['Years_Nominated'],as_index=False).agg({'Country':'first','Nominee':lambda x : ' , '.join(x.astype(str))})
Nominees_DF_2['Years_Nominated']=Nominees_DF_2['Years_Nominated'].astype('int')
Nominees_DF_2=Nominees_DF_2.drop(columns='Country')
Nominees_DF_2=Nominees_DF_2.rename(columns={'Nominee':'Nominees'})

#DF resultante
Nominees_DF_2
# Out:
#     Years_Nominated                                           Nominees
# 0              1901  Jacobus Henricus van 't Hoff , Emil Fischer , ...
# 1              1902  Emil Fischer , Svante Arrhenius , Henri Moissa...
# 2              1903  Svante Arrhenius , Henri Moissan , Marcellin B...
# 3              1904  Henri Moissan , Marcellin Berthelot , William ...
# 4              1905  Henri Moissan , Adolf von Baeyer , Theodore Wi...
# ..              ...                                                ...
# 65             1966  Christopher Kelk Ingold , Alexander Frumkin , ...
# 66             1967  Christopher Kelk Ingold , Alexander Frumkin , ...
# 67             1968  Christopher Kelk Ingold , Henry Eyring , Willi...
# 68             1969  Christopher Kelk Ingold , Walter Heitler , Hen...
# 69             1970  Paul Sabatier , Paul Walden , John Jacob Abel ...
#
# [70 rows x 2 columns]

# %% [markdown]
# ## c) Fuente 3: "Affiliation"

# %%
import pandas as pd

AffiliationLink="https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_university_affiliation"
Affiliation=pd.read_html(AffiliationLink,header=0,flavor='bs4')
type(Affiliation)
# Out:
# list

# %%
Affiliation[0]
# Out:
#                     Laureate              Discipline  Year of award  \
# 0           Alexei Abrikosov                 Physics           2003
# 1               Edgar Adrian  Physiology or Medicine           1932
# 2            Pierre Agostini                 Physics           2023
# 3                 Peter Agre               Chemistry           2003
# 4              Isamu Akasaki                 Physics           2014
# ..                       ...                     ...            ...
# 806            Frits Zernike                 Physics           1953
# 807             Ahmed Zewail               Chemistry           1999
# 808             Karl Ziegler               Chemistry           1963
# 809      Rolf M. Zinkernagel  Physiology or Medicine           1996
# 810  Richard Adolf Zsigmondy               Chemistry           1925
#
#                                 Affiliation
# 0               Argonne National Laboratory
# 1                   University of Cambridge
# 2                     Ohio State University
# 3          Johns Hopkins School of Medicine
# 4                          Meijo University
# ..                                      ...
# 806                 University of Groningen
# 807      California Institute of Technology
# 808  Max Planck Institute for Coal Research
# 809                    University of Zurich
# 810                 University of Göttingen
#
# [811 rows x 4 columns]

# %% [markdown]
# ### c.1) Limpieza de los datos

# %%
Affiliation[0].columns
# Out:
# Index(['Laureate', 'Discipline', 'Year of award', 'Affiliation'], dtype='object')

# %%
#Creando un DF solo con los ganadores al premio Nobel de Química
Affiliation_DF=Affiliation[0].loc[Affiliation[0]['Discipline']=='Chemistry']

#Eliminado la columna 'Discipline' del nuevo DF
Affiliation_DF=Affiliation_DF.drop(columns=['Discipline'])

# Renombrando la columna "Year of award"
Affiliation_DF = Affiliation_DF.rename(columns={"Year of award":"Year_of_award"})
Affiliation_DF
# Out:
#                     Laureate  Year_of_award  \
# 3                 Peter Agre           2003
# 7                 Kurt Alder           1950
# 14             Sidney Altman           1989
# 19     Christian B. Anfinsen           1972
# 23            Frances Arnold           2018
# ..                       ...            ...
# 798            Akira Yoshino           2019
# 799            Akira Yoshino           2019
# 807             Ahmed Zewail           1999
# 808             Karl Ziegler           1963
# 810  Richard Adolf Zsigmondy           1925
#
#                                 Affiliation
# 3          Johns Hopkins School of Medicine
# 7                     University of Cologne
# 14                          Yale University
# 19            National Institutes of Health
# 23       California Institute of Technology
# ..                                      ...
# 798                             Asahi Kasei
# 799                        Meijo University
# 807      California Institute of Technology
# 808  Max Planck Institute for Coal Research
# 810                 University of Göttingen
#
# [211 rows x 3 columns]

# %%
#Ordenando los datos de forma ascendente por año
Affiliation_DF.sort_values(by=['Year_of_award'], inplace=True)
Affiliation_DF.reset_index(inplace=True,drop=True)
Affiliation_DF
# Out:
#                          Laureate  Year_of_award  \
# 0    Jacobus Henricus van 't Hoff           1901
# 1                    Emil Fischer           1902
# 2                Svante Arrhenius           1903
# 3                  William Ramsay           1904
# 4                Adolf von Baeyer           1905
# ..                            ...            ...
# 206              Carolyn Bertozzi           2022
# 207              Morten P. Meldal           2022
# 208          Karl Barry Sharpless           2022
# 209                 Louis E. Brus           2023
# 210                Moungi Bawendi           2023
#
#                                 Affiliation
# 0             Humboldt University of Berlin
# 1             Humboldt University of Berlin
# 2                      Stockholm University
# 3                 University College London
# 4    Ludwig Maximilian University of Munich
# ..                                      ...
# 206         Howard Hughes Medical Institute
# 207                University of Copenhagen
# 208                        Scripps Research
# 209                     Columbia University
# 210   Massachusetts Institute of Technology
#
# [211 rows x 3 columns]

# %% [markdown]
# ## d) Unión (merging) de los tres DFs

# %% [markdown]
# ### d.1) Unión de Nominees_DF_2 y Laureates_DF
# Columnas a emplear para el "merging": 'Years_Nominated' y 'Year_of_award'

# %%
#Verificando que los datos en ambas columnas sean del mismo tipo
Nominees_DF_2.info(), Laureates_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Years_Nominated  70 non-null     int32
#  1   Nominees         70 non-null     object
# dtypes: int32(1), object(1)
# memory usage: 972.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year_of_award     202 non-null    int64
#  1   Laureate          202 non-null    object
#  2   Rationale         202 non-null    object
#  3   Birth_year        202 non-null    object
#  4   Death_year        202 non-null    object
#  5   Country_of_birth  202 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.6+ KB
# (None, None)

# %%
# Merging
Laureates_Nominees_DF=Nominees_DF_2.merge(Laureates_DF,how='right',left_on='Years_Nominated',right_on='Year_of_award')
Laureates_Nominees_DF.drop(columns={'Years_Nominated'}, inplace=True)
Laureates_Nominees_DF
# Out:
#                                               Nominees  Year_of_award  \
# 0    Jacobus Henricus van 't Hoff , Emil Fischer , ...           1901
# 1    Emil Fischer , Svante Arrhenius , Henri Moissa...           1902
# 2    Svante Arrhenius , Henri Moissan , Marcellin B...           1903
# 3    Henri Moissan , Marcellin Berthelot , William ...           1904
# 4    Henri Moissan , Adolf von Baeyer , Theodore Wi...           1905
# ..                                                 ...            ...
# 197                                                NaN           2022
# 198                                                NaN           2022
# 199                                                NaN           2023
# 200                                                NaN           2023
# 201                                                NaN           2023
#
#                          Laureate  \
# 0    Jacobus Henricus van 't Hoff
# 1            Hermann Emil Fischer
# 2         Svante August Arrhenius
# 3              Sir William Ramsay
# 4                Adolf von Baeyer
# ..                            ...
# 197                 Morten Meldal
# 198            K. Barry Sharpless
# 199             Moungi G. Bawendi
# 200                 Louis E. Brus
# 201                 Alexey Ekimov
#
#                                              Rationale Birth_year Death_year  \
# 0    "[for his] discovery of the laws of chemical d...       1852       1911
# 1       "[for] his work on sugar and purine syntheses"       1852       1919
# 2      "[for] his electrolytic theory of dissociation"       1859       1927
# 3    "[for his] discovery of the inert gaseous elem...       1852       1916
# 4    "[for] the advancement of organic chemistry an...       1835       1917
# ..                                                 ...        ...        ...
# 197  "for the development of click chemistry and bi...       1954      Alive
# 198  "for the development of click chemistry and bi...       1941      Alive
# 199  "for the discovery and synthesis of quantum dots"       1961      Alive
# 200  "for the discovery and synthesis of quantum dots"       1943      Alive
# 201  "for the discovery and synthesis of quantum dots"       1945      Alive
#
#     Country_of_birth
# 0        Netherlands
# 1            Germany
# 2             Sweden
# 3     United Kingdom
# 4            Germany
# ..               ...
# 197          Denmark
# 198    United States
# 199    United States
# 200    United States
# 201           Russia
#
# [202 rows x 7 columns]

# %% [markdown]
# ### d.2) Unión de Leaureates_Nominees_DF y Affiliation_DF
# Columna a emplear para el "merging": 'Laureate'

# %% [markdown]
# ### d.2. a) Limpieza de los datos en Affiliation_DF

# %% [markdown]
# **Problema 1**: Revisando la [fuente 3](https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_university_affiliation), ciertos ganadores presentan más de una afiliación y se ha creado una extra fila para cada afiliación. Por tanto, se deberán borrar los duplicados en Affiliation_DF.

# %%
# Filas donde se observan duplicados en las columnas 'Laureate' y 'Year_Won'
Affiliation_DF[Affiliation_DF.duplicated(['Laureate','Year_of_award'],keep=False)]

#Notar que se ha seleccionado ambas columnas, pues dos ganadores (Frederick Sanger y Karl Barry Sharpless) han ganado el premio Nobel en años distintos
# Out:
#                Laureate  Year_of_award  \
# 28           Carl Bosch           1931
# 29    Friedrich Bergius           1931
# 30           Carl Bosch           1931
# 31    Friedrich Bergius           1931
# 36          Peter Debye           1936
# 37          Peter Debye           1936
# 40         Richard Kuhn           1938
# 41         Richard Kuhn           1938
# 42      Adolf Butenandt           1939
# 43      Adolf Butenandt           1939
# 64     Nikolay Semyonov           1956
# 65     Nikolay Semyonov           1956
# 94       Ilya Prigogine           1977
# 95       Ilya Prigogine           1977
# 113     Jean-Marie Lehn           1987
# 115     Jean-Marie Lehn           1987
# 116  Johann Deisenhofer           1988
# 117  Johann Deisenhofer           1988
# 144       Kurt Wüthrich           2002
# 147       Kurt Wüthrich           2002
# 149  Roderick MacKinnon           2003
# 150  Roderick MacKinnon           2003
# 159      Roger Y. Tsien           2008
# 161     Osamu Shimomura           2008
# 162     Osamu Shimomura           2008
# 163      Roger Y. Tsien           2008
# 164    Thomas A. Steitz           2009
# 166    Thomas A. Steitz           2009
# 172    Robert Lefkowitz           2012
# 173    Robert Lefkowitz           2012
# 175      Martin Karplus           2013
# 176      Martin Karplus           2013
# 181         Stefan Hell           2014
# 182         Stefan Hell           2014
# 183     Paul L. Modrich           2015
# 185     Paul L. Modrich           2015
# 186       Tomas Lindahl           2015
# 187       Tomas Lindahl           2015
# 198       Akira Yoshino           2019
# 199       Akira Yoshino           2019
# 205    Carolyn Bertozzi           2022
# 206    Carolyn Bertozzi           2022
#
#                                            Affiliation
# 28                               Heidelberg University
# 29                               Heidelberg University
# 30                                           IG Farben
# 31                                           IG Farben
# 36                       Humboldt University of Berlin
# 37                    Max Planck Institute for Physics
# 40                               Heidelberg University
# 41           Max Planck Institute for Medical Research
# 42                Max Planck Institute of Biochemistry
# 43                       Humboldt University of Berlin
# 64                             Moscow State University
# 65   Institute for Chemical Physics of the Academy ...
# 94                       University of Texas at Austin
# 95                       Université libre de Bruxelles
# 113                           Louis Pasteur University
# 115                                  Collège de France
# 116    University of Texas Southwestern Medical Center
# 117                    Howard Hughes Medical Institute
# 144                                   Scripps Research
# 147                                         ETH Zurich
# 149                    Howard Hughes Medical Institute
# 150                             Rockefeller University
# 159                University of California, San Diego
# 161               Boston University School of Medicine
# 162                       Marine Biological Laboratory
# 163                    Howard Hughes Medical Institute
# 164                    Howard Hughes Medical Institute
# 166                                    Yale University
# 172                     Duke University Medical Center
# 173                    Howard Hughes Medical Institute
# 175                           University of Strasbourg
# 176                                 Harvard University
# 181     Max Planck Institute for Biophysical Chemistry
# 182                      German Cancer Research Center
# 183                    Howard Hughes Medical Institute
# 185                 Duke University School of Medicine
# 186                            Francis Crick Institute
# 187                            Clare Hall laboratories
# 198                                        Asahi Kasei
# 199                                   Meijo University
# 205                                Stanford University
# 206                    Howard Hughes Medical Institute

# %%
# Agrupación de las filas correspondienets al mismo ganador por año, agrupando las afiliaciones por comas en la tercera columna
Affiliation_DF=Affiliation_DF.groupby(['Laureate','Year_of_award'],as_index=False).agg({'Year_of_award':'first','Affiliation':lambda x : ','.join(x.astype(str))})

#Ordenando los datos de forma ascendente por año
Affiliation_DF.sort_values(by=['Year_of_award'], inplace=True)
Affiliation_DF.reset_index(inplace=True,drop=True)
Affiliation_DF
# Out:
#                          Laureate  Year_of_award  \
# 0    Jacobus Henricus van 't Hoff           1901
# 1                    Emil Fischer           1902
# 2                Svante Arrhenius           1903
# 3                  William Ramsay           1904
# 4                Adolf von Baeyer           1905
# ..                            ...            ...
# 185              Carolyn Bertozzi           2022
# 186              Morten P. Meldal           2022
# 187          Karl Barry Sharpless           2022
# 188                 Louis E. Brus           2023
# 189                Moungi Bawendi           2023
#
#                                            Affiliation
# 0                        Humboldt University of Berlin
# 1                        Humboldt University of Berlin
# 2                                 Stockholm University
# 3                            University College London
# 4               Ludwig Maximilian University of Munich
# ..                                                 ...
# 185  Stanford University,Howard Hughes Medical Inst...
# 186                           University of Copenhagen
# 187                                   Scripps Research
# 188                                Columbia University
# 189              Massachusetts Institute of Technology
#
# [190 rows x 3 columns]

# %%
# Revisando nuevamente los duplicados: Se han logrado corregir satisfactoriamente 
Affiliation_DF[Affiliation_DF.duplicated(['Laureate','Year_of_award'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Laureate, Year_of_award, Affiliation]
# Index: []

# %% [markdown]
# ### d.2. b) Fuzzy merging de Leaureates_Nominees_DF y Affiliation_DF

# %% [markdown]
# **Problema 2**: Se busca unir Affiliation_DF y Laureates_DF mediante la columna en común 'Laureate'. Sin embargo, los nombres no se encuentran escritos en el mismo formato, por lo que se deberá realizar un fuzzy merge.

# %%
# Eliminando espacios al inicio y al final
Laureates_Nominees_DF.Laureate=Laureates_Nominees_DF.Laureate.str.strip()
Affiliation_DF.Laureate=Affiliation_DF.Laureate.str.strip()

# Creando sets con los elementos de la columna 'Laureate' en ambos DFs
Laureates_Nominees_set=set(Laureates_Nominees_DF.Laureate)
Affiliation_set=set(Affiliation_DF.Laureate)

# Nombres no comunes en ambas columnas (coindincia menor al 100%)
from thefuzz import process as fz
Laureates_Nominees_set_resta =set((fz.extractOne(f,Laureates_Nominees_set))[0] for f in sorted(Affiliation_set)
   if fz.extractOne(f,Laureates_Nominees_set)[1]<100)

# Tomar un nombre en Affiliation_set y buscar el más similar en Laureates_Nominees_set_resta (en un 86% de coincidencia o más)
changesAff_Laureate = {(f,fz.extractOne(f,Laureates_Nominees_set_resta)) for f in sorted(Affiliation_set)
   if fz.extractOne(f,Laureates_Nominees_set_resta)[1]>86}

# Cambiando los nombres de los ganadores de la columna 'Laureate' en Affiliation_DF 
Affiliation_DF.Laureate.replace(to_replace=changesAff_Laureate,inplace=True)
Affiliation_DF
# Out:
#                          Laureate  Year_of_award  \
# 0    Jacobus Henricus van 't Hoff           1901
# 1                    Emil Fischer           1902
# 2                Svante Arrhenius           1903
# 3                  William Ramsay           1904
# 4                Adolf von Baeyer           1905
# ..                            ...            ...
# 185              Carolyn Bertozzi           2022
# 186              Morten P. Meldal           2022
# 187          Karl Barry Sharpless           2022
# 188                 Louis E. Brus           2023
# 189                Moungi Bawendi           2023
#
#                                            Affiliation
# 0                        Humboldt University of Berlin
# 1                        Humboldt University of Berlin
# 2                                 Stockholm University
# 3                            University College London
# 4               Ludwig Maximilian University of Munich
# ..                                                 ...
# 185  Stanford University,Howard Hughes Medical Inst...
# 186                           University of Copenhagen
# 187                                   Scripps Research
# 188                                Columbia University
# 189              Massachusetts Institute of Technology
#
# [190 rows x 3 columns]

# %%
# Nombres faltantes
# Nota: Affiliation_DF tiene 190 filas y Laureates_Nominees_DF, 194 (no hay información de afiliación de todos los ganadores)
Laureates_Nominees_set=set(Laureates_Nominees_DF.Laureate)
Affiliation_set2=set(Affiliation_DF.Laureate)

{f:fz.extractOne(f,Laureates_Nominees_set)[0] for f in sorted(Affiliation_set)
   if fz.extractOne(f,Laureates_Nominees_set)[1]<=86}
# Out:
# {'Adolf Butenandt': 'Richard Adolf Zsigmondy',
#  'Adolf Windaus': 'Richard Adolf Zsigmondy',
#  'Archer Martin': 'Archer John Porter Martin',
#  'Arne Tiselius': 'Arne Wilhelm Kaurin Tiselius',
#  'Derek Barton': 'Derek H. R. Barton',
#  'Dorothy Hodgkin': 'Dorothy Crowfoot Hodgkin',
#  'Edwin McMillan': 'Edwin Mattison McMillan',
#  'Hans von Euler-Chelpin': 'Hans Fischer',
#  'Harold Urey': 'Harold Clayton Urey',
#  'Harry Kroto': 'Sir Harold W. Kroto',
#  'James B. Sumner': 'James Batcheller Sumner',
#  'Jens Christian Skou': 'Jens C. Skou',
#  'John Cornforth': 'Archer John Porter Martin',
#  'John Kendrew': 'John Howard Northrop',
#  'Max Perutz': 'Max Ferdinand Perutz',
#  'Nikolay Semyonov': 'Nikolay Nikolaevich Semenov',
#  'Otto Diels': 'Heinrich Otto Wieland',
#  'Robert Curl': 'Robert F. Curl Jr.',
#  'Venki Ramakrishnan': 'Venkatraman Ramakrishnan',
#  'Walther Nernst': 'Walther Hermann Nernst',
#  'William Giauque': 'William Francis Giauque'}

# %%
# Corrigiendo manualmente los nombres faltantes (hay errores en algunos resultados y estos han sido señalados)
changesAff_Laureate2= {'Adolf Butenandt': 'Adolf Friedrich Johann Butenandt', #corrección manual
 'Adolf Windaus': 'Adolf Otto Reinhold Windaus',
 'Archer Martin': 'Archer John Porter Martin',
 'Arne Tiselius': 'Arne Wilhelm Kaurin Tiselius',
 'Derek Barton': 'Derek H. R. Barton',
 'Dorothy Hodgkin': 'Dorothy Crowfoot Hodgkin',
 'Edwin McMillan': 'Edwin Mattison McMillan',
 'Hans von Euler-Chelpin': 'Hans Karl August Simon von Euler-Chelpin', #corrección manual
 'Harold Urey': 'Harold Clayton Urey', #corrección manual
 'Harry Kroto': 'Sir Harold W. Kroto',
 'James B. Sumner': 'James Batcheller Sumner',
 'Jens Christian Skou': 'Jens C. Skou',
 'John Cornforth': 'John Warcup Cornforth', #corrección manual
 'John Kendrew': 'John Cowdery Kendrew',
 'Max Perutz': 'Max Ferdinand Perutz',
 'Nikolay Semyonov': 'Nikolay Nikolaevich Semenov',
 'Otto Diels': 'Otto Paul Hermann Diels',
 'Robert Curl': 'Robert F. Curl Jr.', #corrección manual
 'Venki Ramakrishnan': 'Venkatraman Ramakrishnan',
 'Walther Nernst': 'Walther Hermann Nernst',
 'William Giauque': 'William Francis Giauque'} #corrección manual

Affiliation_DF.Laureate.replace(to_replace=changesAff_Laureate2,inplace=True)
Affiliation_DF
# Out:
#                          Laureate  Year_of_award  \
# 0    Jacobus Henricus van 't Hoff           1901
# 1                    Emil Fischer           1902
# 2                Svante Arrhenius           1903
# 3                  William Ramsay           1904
# 4                Adolf von Baeyer           1905
# ..                            ...            ...
# 185              Carolyn Bertozzi           2022
# 186              Morten P. Meldal           2022
# 187          Karl Barry Sharpless           2022
# 188                 Louis E. Brus           2023
# 189                Moungi Bawendi           2023
#
#                                            Affiliation
# 0                        Humboldt University of Berlin
# 1                        Humboldt University of Berlin
# 2                                 Stockholm University
# 3                            University College London
# 4               Ludwig Maximilian University of Munich
# ..                                                 ...
# 185  Stanford University,Howard Hughes Medical Inst...
# 186                           University of Copenhagen
# 187                                   Scripps Research
# 188                                Columbia University
# 189              Massachusetts Institute of Technology
#
# [190 rows x 3 columns]

# %%
# Verificando que todos los nombres hayan sido reemplazados con sus análogos
Laureates_Nominees_set=set(Laureates_Nominees_DF.Laureate)
Affiliation_set3=set(Affiliation_DF.Laureate)

Affiliation_set3-Laureates_Nominees_set  

# Ya se han reemplazado todos, pues el set está vacío
# Out:
# {'Ada Yonath',
#  'Alan MacDiarmid',
#  'Alexander R. Todd',
#  'Cyril Norman Hinshelwood',
#  'David MacMillan',
#  'Emil Fischer',
#  'F. Sherwood Rowland',
#  'Frédéric Joliot-Curie',
#  'George Andrew Olah',
#  'George P. Smith',
#  'Glenn T. Seaborg',
#  'Gregory Winter',
#  'John Polanyi',
#  'John Pople',
#  'Karl Barry Sharpless',
#  'Luis Federico Leloir',
#  'Marie Curie',
#  'Mario Molina',
#  'Morten P. Meldal',
#  'Moungi Bawendi',
#  'Norman Haworth',
#  'Paul Flory',
#  'Richard Smalley',
#  'Richard Willstätter',
#  'Robert Robinson',
#  'Stefan Hell',
#  'Svante Arrhenius',
#  'Theodor Svedberg',
#  'Willard Libby',
#  'William Howard Stein',
#  'William Lipscomb',
#  'William Ramsay'}

# %% [markdown]
# ### d.2. c) Unión de Leaureates_Nominees_DF y Affiliation_DF

# %%
# Verificando que los datos de la columna "Laureate" son del mismo tipo en ambos DF
Affiliation_DF.info(),Laureates_Nominees_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Laureate       190 non-null    object
#  1   Year_of_award  190 non-null    int64
#  2   Affiliation    190 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nominees          87 non-null     object
#  1   Year_of_award     202 non-null    int64
#  2   Laureate          202 non-null    object
#  3   Rationale         202 non-null    object
#  4   Birth_year        202 non-null    object
#  5   Death_year        202 non-null    object
#  6   Country_of_birth  202 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 11.2+ KB
# (None, None)

# %%
# Finalmente: Merging
Laureates_Nominees_Affiliation_DF=Affiliation_DF.merge(Laureates_Nominees_DF,how='right',left_on='Laureate',right_on='Laureate')
Laureates_Nominees_Affiliation_DF
# Out:
#                          Laureate  Year_of_award_x  \
# 0    Jacobus Henricus van 't Hoff           1901.0
# 1            Hermann Emil Fischer              NaN
# 2         Svante August Arrhenius              NaN
# 3              Sir William Ramsay              NaN
# 4                Adolf von Baeyer           1905.0
# ..                            ...              ...
# 199                 Morten Meldal              NaN
# 200            K. Barry Sharpless              NaN
# 201             Moungi G. Bawendi              NaN
# 202                 Louis E. Brus           2023.0
# 203                 Alexey Ekimov              NaN
#
#                                 Affiliation  \
# 0             Humboldt University of Berlin
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4    Ludwig Maximilian University of Munich
# ..                                      ...
# 199                                     NaN
# 200                                     NaN
# 201                                     NaN
# 202                     Columbia University
# 203                                     NaN
#
#                                               Nominees  Year_of_award_y  \
# 0    Jacobus Henricus van 't Hoff , Emil Fischer , ...             1901
# 1    Emil Fischer , Svante Arrhenius , Henri Moissa...             1902
# 2    Svante Arrhenius , Henri Moissan , Marcellin B...             1903
# 3    Henri Moissan , Marcellin Berthelot , William ...             1904
# 4    Henri Moissan , Adolf von Baeyer , Theodore Wi...             1905
# ..                                                 ...              ...
# 199                                                NaN             2022
# 200                                                NaN             2022
# 201                                                NaN             2023
# 202                                                NaN             2023
# 203                                                NaN             2023
#
#                                              Rationale Birth_year Death_year  \
# 0    "[for his] discovery of the laws of chemical d...       1852       1911
# 1       "[for] his work on sugar and purine syntheses"       1852       1919
# 2      "[for] his electrolytic theory of dissociation"       1859       1927
# 3    "[for his] discovery of the inert gaseous elem...       1852       1916
# 4    "[for] the advancement of organic chemistry an...       1835       1917
# ..                                                 ...        ...        ...
# 199  "for the development of click chemistry and bi...       1954      Alive
# 200  "for the development of click chemistry and bi...       1941      Alive
# 201  "for the discovery and synthesis of quantum dots"       1961      Alive
# 202  "for the discovery and synthesis of quantum dots"       1943      Alive
# 203  "for the discovery and synthesis of quantum dots"       1945      Alive
#
#     Country_of_birth
# 0        Netherlands
# 1            Germany
# 2             Sweden
# 3     United Kingdom
# 4            Germany
# ..               ...
# 199          Denmark
# 200    United States
# 201    United States
# 202    United States
# 203           Russia
#
# [204 rows x 9 columns]

# %%
Laureates_Nominees_Affiliation_DF=Affiliation_DF.merge(Laureates_Nominees_DF,how='right',left_on='Laureate',right_on='Laureate')

#Limpiando el DF resultante
Laureates_Nominees_Affiliation_DF.drop(columns='Year_of_award_x', inplace=True)
Laureates_Nominees_Affiliation_DF=Laureates_Nominees_Affiliation_DF.rename(columns={'Year_of_award_y':'Year_of_award'})

#Ordenando columnas
Laureates_Nominees_Affiliation_DF=Laureates_Nominees_Affiliation_DF.reindex(columns=['Year_of_award','Nominees','Laureate','Birth_year','Death_year','Affiliation','Rationale','Country_of_birth'])
Laureates_Nominees_Affiliation_DF
# Out:
#      Year_of_award                                           Nominees  \
# 0             1901  Jacobus Henricus van 't Hoff , Emil Fischer , ...
# 1             1902  Emil Fischer , Svante Arrhenius , Henri Moissa...
# 2             1903  Svante Arrhenius , Henri Moissan , Marcellin B...
# 3             1904  Henri Moissan , Marcellin Berthelot , William ...
# 4             1905  Henri Moissan , Adolf von Baeyer , Theodore Wi...
# ..             ...                                                ...
# 199           2022                                                NaN
# 200           2022                                                NaN
# 201           2023                                                NaN
# 202           2023                                                NaN
# 203           2023                                                NaN
#
#                          Laureate Birth_year Death_year  \
# 0    Jacobus Henricus van 't Hoff       1852       1911
# 1            Hermann Emil Fischer       1852       1919
# 2         Svante August Arrhenius       1859       1927
# 3              Sir William Ramsay       1852       1916
# 4                Adolf von Baeyer       1835       1917
# ..                            ...        ...        ...
# 199                 Morten Meldal       1954      Alive
# 200            K. Barry Sharpless       1941      Alive
# 201             Moungi G. Bawendi       1961      Alive
# 202                 Louis E. Brus       1943      Alive
# 203                 Alexey Ekimov       1945      Alive
#
#                                 Affiliation  \
# 0             Humboldt University of Berlin
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4    Ludwig Maximilian University of Munich
# ..                                      ...
# 199                                     NaN
# 200                                     NaN
# 201                                     NaN
# 202                     Columbia University
# 203                                     NaN
#
#                                              Rationale Country_of_birth
# 0    "[for his] discovery of the laws of chemical d...      Netherlands
# 1       "[for] his work on sugar and purine syntheses"          Germany
# 2      "[for] his electrolytic theory of dissociation"           Sweden
# 3    "[for his] discovery of the inert gaseous elem...   United Kingdom
# 4    "[for] the advancement of organic chemistry an...          Germany
# ..                                                 ...              ...
# 199  "for the development of click chemistry and bi...          Denmark
# 200  "for the development of click chemistry and bi...    United States
# 201  "for the discovery and synthesis of quantum dots"    United States
# 202  "for the discovery and synthesis of quantum dots"    United States
# 203  "for the discovery and synthesis of quantum dots"           Russia
#
# [204 rows x 8 columns]

# %%
#Revisando si hay duplicados en ciertas filas
Laureates_Nominees_Affiliation_DF[Laureates_Nominees_Affiliation_DF.duplicated(['Laureate','Year_of_award'],keep=False)]
# Out:
#      Year_of_award                                           Nominees  \
# 69            1958  Walther Nernst , Otto Hahn , Lise Meitner , Pa...
# 70            1958  Walther Nernst , Otto Hahn , Lise Meitner , Pa...
# 104           1980                                                NaN
# 105           1980                                                NaN
#
#              Laureate Birth_year Death_year  \
# 69   Frederick Sanger       1918       2013
# 70   Frederick Sanger       1918       2013
# 104  Frederick Sanger       1918       2013
# 105  Frederick Sanger       1918       2013
#
#                              Affiliation  \
# 69               University of Cambridge
# 70   MRC Laboratory of Molecular Biology
# 104              University of Cambridge
# 105  MRC Laboratory of Molecular Biology
#
#                                              Rationale Country_of_birth
# 69   "for his work on the structure of proteins, es...   United Kingdom
# 70   "for his work on the structure of proteins, es...   United Kingdom
# 104  "for their contributions concerning the determ...   United Kingdom
# 105  "for their contributions concerning the determ...   United Kingdom

# %%
# Eliminando una de las filas duplicadas
Laureates_Nominees_Affiliation_DF.drop([70,105,148,202],axis=0, inplace = True)
Laureates_Nominees_Affiliation_DF.reset_index(inplace=True,drop=True)

#Resultado
Laureates_Nominees_Affiliation_DF
# Out:
#      Year_of_award                                           Nominees  \
# 0             1901  Jacobus Henricus van 't Hoff , Emil Fischer , ...
# 1             1902  Emil Fischer , Svante Arrhenius , Henri Moissa...
# 2             1903  Svante Arrhenius , Henri Moissan , Marcellin B...
# 3             1904  Henri Moissan , Marcellin Berthelot , William ...
# 4             1905  Henri Moissan , Adolf von Baeyer , Theodore Wi...
# ..             ...                                                ...
# 195           2022                                                NaN
# 196           2022                                                NaN
# 197           2022                                                NaN
# 198           2023                                                NaN
# 199           2023                                                NaN
#
#                          Laureate Birth_year Death_year  \
# 0    Jacobus Henricus van 't Hoff       1852       1911
# 1            Hermann Emil Fischer       1852       1919
# 2         Svante August Arrhenius       1859       1927
# 3              Sir William Ramsay       1852       1916
# 4                Adolf von Baeyer       1835       1917
# ..                            ...        ...        ...
# 195              Carolyn Bertozzi       1966      Alive
# 196                 Morten Meldal       1954      Alive
# 197            K. Barry Sharpless       1941      Alive
# 198             Moungi G. Bawendi       1961      Alive
# 199                 Alexey Ekimov       1945      Alive
#
#                                            Affiliation  \
# 0                        Humboldt University of Berlin
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4               Ludwig Maximilian University of Munich
# ..                                                 ...
# 195  Stanford University,Howard Hughes Medical Inst...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                              Rationale Country_of_birth
# 0    "[for his] discovery of the laws of chemical d...      Netherlands
# 1       "[for] his work on sugar and purine syntheses"          Germany
# 2      "[for] his electrolytic theory of dissociation"           Sweden
# 3    "[for his] discovery of the inert gaseous elem...   United Kingdom
# 4    "[for] the advancement of organic chemistry an...          Germany
# ..                                                 ...              ...
# 195  "for the development of click chemistry and bi...    United States
# 196  "for the development of click chemistry and bi...          Denmark
# 197  "for the development of click chemistry and bi...    United States
# 198  "for the discovery and synthesis of quantum dots"    United States
# 199  "for the discovery and synthesis of quantum dots"           Russia
#
# [200 rows x 8 columns]

# %%
#Revisando nuevamente si hay duplicados en ciertas filas: No hay
Laureates_Nominees_Affiliation_DF[Laureates_Nominees_Affiliation_DF.duplicated(['Laureate','Year_of_award'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Year_of_award, Nominees, Laureate, Birth_year, Death_year, Affiliation, Rationale, Country_of_birth]
# Index: []

# %% [markdown]
# ## e) Unión (merging) de Laureates_Nominees_Affiliation_DF (Nobel_Chemistry_DF) con el archivo adjunto
# Columnas a emplear para el "merging": 'Country_of_birth' y 'Country'

# %%
Nobel_Chemistry_DF = Laureates_Nominees_Affiliation_DF.copy()

country_isos=pd.read_excel('https://github.com/Ciencia-de-datos-espaciales-2023-2/Ejercicio_2/raw/main/country_isos.xlsx')
country_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %% [markdown]
# ### e.1) Fuzzy merging de Nobel_Chemistry_DF y country.isos
# **Problema**: Los nombres de los países no se encuentran escritos en el mismo formato, por lo que se deberá realizar un fuzzy merge.

# %%
# Fuzzy merge de los nombres de los países de Nobel_Chemistry_DF y country_isos
Nobel_Chemistry_DF_set=set(Nobel_Chemistry_DF.Country_of_birth)
country_isos_set=set(country_isos.Country)

# Nombres de países no comunes en ambas columnas (coindincia menor al 100%)
from thefuzz import process as fz
country_isos_set_resta={(fz.extractOne(f,country_isos_set))[0] for f in sorted(Nobel_Chemistry_DF_set)
   if fz.extractOne(f,country_isos_set)[1]<100}

# Cambiando los nombres de los países de nacimiento en Nobel_Chemistry_DF
changes_Country={f:fz.extractOne(f,country_isos_set_resta)[0] for f in sorted(Nobel_Chemistry_DF_set)
   if fz.extractOne(f,country_isos_set_resta)[1]>=95}

Nobel_Chemistry_DF.replace(to_replace=changes_Country,inplace=True)

# %%
# Nombres faltantes
Nobel_Chemistry_DF_set=set(Nobel_Chemistry_DF.Country_of_birth)
country_isos_set=set(country_isos.Country)

# Tomar un nombre en Nobel_Chemistry_DF_set y buscar el más similar en country_isos_set
from thefuzz import process as fz
changes_Country2={f:fz.extractOne(f,country_isos_set)[0] for f in sorted(Nobel_Chemistry_DF_set)
   if fz.extractOne(f,country_isos_set)[1]<95}

changes_Country2
# Out:
# {'Czechoslovakia': 'SLOVAKIA',
#  'Israel': 'IRAQ',
#  'Kingdom of Yugoslavia': 'CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#  'Not awarded': 'QATAR',
#  'Russia': 'RUSSIAN FEDERATION (THE)',
#  'Soviet Union': 'VIET NAM',
#  'United Kingdom': 'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#  'United States': 'UNITED STATES MINOR OUTLYING ISLANDS (THE)',
#  'West Germany': 'GERMANY',
#  'Yugoslavia': 'LATVIA'}

# %%
# Ciertos países tienen que reescribirse manualmente, porque algunos ya no existen (ejm: Yugoslavia,Czechoslovakia)
# Se han señalado las que se han corregido a mano. Para las correciones, se ha tenido que revisar la fuente 1.

changes_Country3= {
    'Czechoslovakia': 'CZECHIA', 
    #corrección: Czechoslovakia es actualmente un territorio que comprende República Checa y eslovakia, 
    # pero Jaroslav Heyrovský nació en Praga, perteneciente a República Checa
 'Israel': 'ISRAEL', 
    #NOTA: Israel no se encuentra en el el archivo adjunto
 'Kingdom of Yugoslavia': 'CROATIA', 
    # corrección Leopold Ružička nació en Vukovar, Yugoslavia (actual CROACIA)
 'Not awarded': 'Not awarded', 
    #corrección
 'Russia': 'RUSSIAN FEDERATION (THE)',
 'Soviet Union': 'RUSSIAN FEDERATION (THE)', 
    #corrección: Nikolay Nikolaevich Semenov nació en Saratov Oblast, Russia (antigua Unión Soviética)
 'United Kingdom': 'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
 'United States': 'UNITED STATES MINOR OUTLYING ISLANDS (THE)',
 'West Germany': 'GERMANY', 
 'Yugoslavia': 'BOSNIA AND HERZEGOVINA'} 
    #corrección: Vladimir Prelog nació en  Sarajevo, Yugoslavia (actual Bosnia y Hersegovina)

Nobel_Chemistry_DF.replace(to_replace=changes_Country3,inplace=True)

# %% [markdown]
# ### e.2) Merging de Nobel_Chemistry_DF y country.isos

# %%
# Merging
Nobel_Chemistry_countryisos_DF=Nobel_Chemistry_DF.merge(country_isos,how='left',right_on='Country',left_on='Country_of_birth')
Nobel_Chemistry_countryisos_DF.drop(columns={'Country'}, inplace=True)

#Resultado final
Nobel_Chemistry_countryisos_DF.to_csv("Nobel_Chemistry_countryisos_DF.csv")
Nobel_Chemistry_countryisos_DF
# Out:
#      Year_of_award                                           Nominees  \
# 0             1901  Jacobus Henricus van 't Hoff , Emil Fischer , ...
# 1             1902  Emil Fischer , Svante Arrhenius , Henri Moissa...
# 2             1903  Svante Arrhenius , Henri Moissan , Marcellin B...
# 3             1904  Henri Moissan , Marcellin Berthelot , William ...
# 4             1905  Henri Moissan , Adolf von Baeyer , Theodore Wi...
# ..             ...                                                ...
# 197           2022                                                NaN
# 198           2022                                                NaN
# 199           2023                                                NaN
# 200           2023                                                NaN
# 201           2023                                                NaN
#
#                          Laureate Birth_year Death_year  \
# 0    Jacobus Henricus van 't Hoff       1852       1911
# 1            Hermann Emil Fischer       1852       1919
# 2         Svante August Arrhenius       1859       1927
# 3              Sir William Ramsay       1852       1916
# 4                Adolf von Baeyer       1835       1917
# ..                            ...        ...        ...
# 197                 Morten Meldal       1954      Alive
# 198            K. Barry Sharpless       1941      Alive
# 199             Moungi G. Bawendi       1961      Alive
# 200                 Louis E. Brus       1943      Alive
# 201                 Alexey Ekimov       1945      Alive
#
#                                 Affiliation  \
# 0             Humboldt University of Berlin
# 1             Humboldt University of Berlin
# 2                      Stockholm University
# 3                 University College London
# 4    Ludwig Maximilian University of Munich
# ..                                      ...
# 197                University of Copenhagen
# 198                        Scripps Research
# 199   Massachusetts Institute of Technology
# 200                     Columbia University
# 201                                     NaN
#
#                                              Rationale  \
# 0    "[for his] discovery of the laws of chemical d...
# 1       "[for] his work on sugar and purine syntheses"
# 2      "[for] his electrolytic theory of dissociation"
# 3    "[for his] discovery of the inert gaseous elem...
# 4    "[for] the advancement of organic chemistry an...
# ..                                                 ...
# 197  "for the development of click chemistry and bi...
# 198  "for the development of click chemistry and bi...
# 199  "for the discovery and synthesis of quantum dots"
# 200  "for the discovery and synthesis of quantum dots"
# 201  "for the discovery and synthesis of quantum dots"
#
#                                       Country_of_birth  \
# 0                                    NETHERLANDS (THE)
# 1                                              GERMANY
# 2                                               SWEDEN
# 3    UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...
# 4                                              GERMANY
# ..                                                 ...
# 197                                            DENMARK
# 198         UNITED STATES MINOR OUTLYING ISLANDS (THE)
# 199         UNITED STATES MINOR OUTLYING ISLANDS (THE)
# 200         UNITED STATES MINOR OUTLYING ISLANDS (THE)
# 201                           RUSSIAN FEDERATION (THE)
#
#                                      Officialstatename InternetccTLD iso2 iso3
# 0                       The Kingdom of the Netherlands           .nl   NL  NLD
# 1                      The Federal Republic of Germany           .de   DE  DEU
# 2                                The Kingdom of Sweden           .se   SE  SWE
# 3    The United Kingdom of Great Britain and Northe...           .uk   GB  GBR
# 4                      The Federal Republic of Germany           .de   DE  DEU
# ..                                                 ...           ...  ...  ...
# 197                             The Kingdom of Denmark           .dk   DK  DNK
# 198  Baker¬†Island, Howland¬†Island, Jarvis¬†Island...           NaN   UM  UMI
# 199  Baker¬†Island, Howland¬†Island, Jarvis¬†Island...           NaN   UM  UMI
# 200  Baker¬†Island, Howland¬†Island, Jarvis¬†Island...           NaN   UM  UMI
# 201                             The Russian Federation           .ru   RU  RUS
#
# [202 rows x 12 columns]

# %%
#Transformación de la tabla a horizontal para clasificar a los ganadores por país de nacimiento
Nobel_Chemistry_countryisos_DF_wide=pd.pivot_table(Nobel_Chemistry_countryisos_DF,
               values=["Laureate"], # values to use
               index=['Country_of_birth'], # unit of analysis
               columns=['Year_of_award'], # the values for NEW column
                aggfunc=lambda x: ' '.join(str(v) for v in x))

Nobel_Chemistry_countryisos_DF_wide
# Out:
#                                                                         Laureate  \
# Year_of_award                                                               1901
# Country_of_birth
# ARGENTINA                                                                    NaN
# AUSTRALIA                                                                    NaN
# AUSTRIA                                                                      NaN
# BELGIUM                                                                      NaN
# BOSNIA AND HERZEGOVINA                                                       NaN
# CANADA                                                                       NaN
# CROATIA                                                                      NaN
# CZECHIA                                                                      NaN
# DENMARK                                                                      NaN
# FINLAND                                                                      NaN
# FRANCE                                                                       NaN
# GERMANY                                                                      NaN
# HUNGARY                                                                      NaN
# ISRAEL                                                                       NaN
# ITALY                                                                        NaN
# JAPAN                                                                        NaN
# MEXICO                                                                       NaN
# NETHERLANDS (THE)                                   Jacobus Henricus van 't Hoff
# NORWAY                                                                       NaN
# Not awarded                                                                  NaN
# POLAND                                                                       NaN
# RUSSIAN FEDERATION (THE)                                                     NaN
# SWEDEN                                                                       NaN
# SWITZERLAND                                                                  NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                           NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                                   NaN
#
#                                                                           \
# Year_of_award                                                       1902
# Country_of_birth
# ARGENTINA                                                            NaN
# AUSTRALIA                                                            NaN
# AUSTRIA                                                              NaN
# BELGIUM                                                              NaN
# BOSNIA AND HERZEGOVINA                                               NaN
# CANADA                                                               NaN
# CROATIA                                                              NaN
# CZECHIA                                                              NaN
# DENMARK                                                              NaN
# FINLAND                                                              NaN
# FRANCE                                                               NaN
# GERMANY                                             Hermann Emil Fischer
# HUNGARY                                                              NaN
# ISRAEL                                                               NaN
# ITALY                                                                NaN
# JAPAN                                                                NaN
# MEXICO                                                               NaN
# NETHERLANDS (THE)                                                    NaN
# NORWAY                                                               NaN
# Not awarded                                                          NaN
# POLAND                                                               NaN
# RUSSIAN FEDERATION (THE)                                             NaN
# SWEDEN                                                               NaN
# SWITZERLAND                                                          NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                   NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                           NaN
#
#                                                                              \
# Year_of_award                                                          1903
# Country_of_birth
# ARGENTINA                                                               NaN
# AUSTRALIA                                                               NaN
# AUSTRIA                                                                 NaN
# BELGIUM                                                                 NaN
# BOSNIA AND HERZEGOVINA                                                  NaN
# CANADA                                                                  NaN
# CROATIA                                                                 NaN
# CZECHIA                                                                 NaN
# DENMARK                                                                 NaN
# FINLAND                                                                 NaN
# FRANCE                                                                  NaN
# GERMANY                                                                 NaN
# HUNGARY                                                                 NaN
# ISRAEL                                                                  NaN
# ITALY                                                                   NaN
# JAPAN                                                                   NaN
# MEXICO                                                                  NaN
# NETHERLANDS (THE)                                                       NaN
# NORWAY                                                                  NaN
# Not awarded                                                             NaN
# POLAND                                                                  NaN
# RUSSIAN FEDERATION (THE)                                                NaN
# SWEDEN                                              Svante August Arrhenius
# SWITZERLAND                                                             NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                      NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                              NaN
#
#                                                                         \
# Year_of_award                                                     1904
# Country_of_birth
# ARGENTINA                                                          NaN
# AUSTRALIA                                                          NaN
# AUSTRIA                                                            NaN
# BELGIUM                                                            NaN
# BOSNIA AND HERZEGOVINA                                             NaN
# CANADA                                                             NaN
# CROATIA                                                            NaN
# CZECHIA                                                            NaN
# DENMARK                                                            NaN
# FINLAND                                                            NaN
# FRANCE                                                             NaN
# GERMANY                                                            NaN
# HUNGARY                                                            NaN
# ISRAEL                                                             NaN
# ITALY                                                              NaN
# JAPAN                                                              NaN
# MEXICO                                                             NaN
# NETHERLANDS (THE)                                                  NaN
# NORWAY                                                             NaN
# Not awarded                                                        NaN
# POLAND                                                             NaN
# RUSSIAN FEDERATION (THE)                                           NaN
# SWEDEN                                                             NaN
# SWITZERLAND                                                        NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...  Sir William Ramsay
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                         NaN
#
#                                                                       \
# Year_of_award                                                   1905
# Country_of_birth
# ARGENTINA                                                        NaN
# AUSTRALIA                                                        NaN
# AUSTRIA                                                          NaN
# BELGIUM                                                          NaN
# BOSNIA AND HERZEGOVINA                                           NaN
# CANADA                                                           NaN
# CROATIA                                                          NaN
# CZECHIA                                                          NaN
# DENMARK                                                          NaN
# FINLAND                                                          NaN
# FRANCE                                                           NaN
# GERMANY                                             Adolf von Baeyer
# HUNGARY                                                          NaN
# ISRAEL                                                           NaN
# ITALY                                                            NaN
# JAPAN                                                            NaN
# MEXICO                                                           NaN
# NETHERLANDS (THE)                                                NaN
# NORWAY                                                           NaN
# Not awarded                                                      NaN
# POLAND                                                           NaN
# RUSSIAN FEDERATION (THE)                                         NaN
# SWEDEN                                                           NaN
# SWITZERLAND                                                      NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...               NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                       NaN
#
#                                                                    \
# Year_of_award                                                1906
# Country_of_birth
# ARGENTINA                                                     NaN
# AUSTRALIA                                                     NaN
# AUSTRIA                                                       NaN
# BELGIUM                                                       NaN
# BOSNIA AND HERZEGOVINA                                        NaN
# CANADA                                                        NaN
# CROATIA                                                       NaN
# CZECHIA                                                       NaN
# DENMARK                                                       NaN
# FINLAND                                                       NaN
# FRANCE                                              Henri Moissan
# GERMANY                                                       NaN
# HUNGARY                                                       NaN
# ISRAEL                                                        NaN
# ITALY                                                         NaN
# JAPAN                                                         NaN
# MEXICO                                                        NaN
# NETHERLANDS (THE)                                             NaN
# NORWAY                                                        NaN
# Not awarded                                                   NaN
# POLAND                                                        NaN
# RUSSIAN FEDERATION (THE)                                      NaN
# SWEDEN                                                        NaN
# SWITZERLAND                                                   NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...            NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                    NaN
#
#                                                                     \
# Year_of_award                                                 1907
# Country_of_birth
# ARGENTINA                                                      NaN
# AUSTRALIA                                                      NaN
# AUSTRIA                                                        NaN
# BELGIUM                                                        NaN
# BOSNIA AND HERZEGOVINA                                         NaN
# CANADA                                                         NaN
# CROATIA                                                        NaN
# CZECHIA                                                        NaN
# DENMARK                                                        NaN
# FINLAND                                                        NaN
# FRANCE                                                         NaN
# GERMANY                                             Eduard Buchner
# HUNGARY                                                        NaN
# ISRAEL                                                         NaN
# ITALY                                                          NaN
# JAPAN                                                          NaN
# MEXICO                                                         NaN
# NETHERLANDS (THE)                                              NaN
# NORWAY                                                         NaN
# Not awarded                                                    NaN
# POLAND                                                         NaN
# RUSSIAN FEDERATION (THE)                                       NaN
# SWEDEN                                                         NaN
# SWITZERLAND                                                    NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...             NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                     NaN
#
#                                                                        \
# Year_of_award                                                    1908
# Country_of_birth
# ARGENTINA                                                         NaN
# AUSTRALIA                                                         NaN
# AUSTRIA                                                           NaN
# BELGIUM                                                           NaN
# BOSNIA AND HERZEGOVINA                                            NaN
# CANADA                                                            NaN
# CROATIA                                                           NaN
# CZECHIA                                                           NaN
# DENMARK                                                           NaN
# FINLAND                                                           NaN
# FRANCE                                                            NaN
# GERMANY                                                           NaN
# HUNGARY                                                           NaN
# ISRAEL                                                            NaN
# ITALY                                                             NaN
# JAPAN                                                             NaN
# MEXICO                                                            NaN
# NETHERLANDS (THE)                                                 NaN
# NORWAY                                                            NaN
# Not awarded                                                       NaN
# POLAND                                                            NaN
# RUSSIAN FEDERATION (THE)                                          NaN
# SWEDEN                                                            NaN
# SWITZERLAND                                                       NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...  Ernest Rutherford
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                        NaN
#
#                                                                      \
# Year_of_award                                                  1909
# Country_of_birth
# ARGENTINA                                                       NaN
# AUSTRALIA                                                       NaN
# AUSTRIA                                                         NaN
# BELGIUM                                                         NaN
# BOSNIA AND HERZEGOVINA                                          NaN
# CANADA                                                          NaN
# CROATIA                                                         NaN
# CZECHIA                                                         NaN
# DENMARK                                                         NaN
# FINLAND                                                         NaN
# FRANCE                                                          NaN
# GERMANY                                             Wilhelm Ostwald
# HUNGARY                                                         NaN
# ISRAEL                                                          NaN
# ITALY                                                           NaN
# JAPAN                                                           NaN
# MEXICO                                                          NaN
# NETHERLANDS (THE)                                               NaN
# NORWAY                                                          NaN
# Not awarded                                                     NaN
# POLAND                                                          NaN
# RUSSIAN FEDERATION (THE)                                        NaN
# SWEDEN                                                          NaN
# SWITZERLAND                                                     NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...              NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                      NaN
#
#                                                                   ...  \
# Year_of_award                                               1910  ...
# Country_of_birth                                                  ...
# ARGENTINA                                                    NaN  ...
# AUSTRALIA                                                    NaN  ...
# AUSTRIA                                                      NaN  ...
# BELGIUM                                                      NaN  ...
# BOSNIA AND HERZEGOVINA                                       NaN  ...
# CANADA                                                       NaN  ...
# CROATIA                                                      NaN  ...
# CZECHIA                                                      NaN  ...
# DENMARK                                                      NaN  ...
# FINLAND                                                      NaN  ...
# FRANCE                                                       NaN  ...
# GERMANY                                             Otto Wallach  ...
# HUNGARY                                                      NaN  ...
# ISRAEL                                                       NaN  ...
# ITALY                                                        NaN  ...
# JAPAN                                                        NaN  ...
# MEXICO                                                       NaN  ...
# NETHERLANDS (THE)                                            NaN  ...
# NORWAY                                                       NaN  ...
# Not awarded                                                  NaN  ...
# POLAND                                                       NaN  ...
# RUSSIAN FEDERATION (THE)                                     NaN  ...
# SWEDEN                                                       NaN  ...
# SWITZERLAND                                                  NaN  ...
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...           NaN  ...
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                   NaN  ...
#
#                                                                                     \
# Year_of_award                                                                 2014
# Country_of_birth
# ARGENTINA                                                                      NaN
# AUSTRALIA                                                                      NaN
# AUSTRIA                                                                        NaN
# BELGIUM                                                                        NaN
# BOSNIA AND HERZEGOVINA                                                         NaN
# CANADA                                                                         NaN
# CROATIA                                                                        NaN
# CZECHIA                                                                        NaN
# DENMARK                                                                        NaN
# FINLAND                                                                        NaN
# FRANCE                                                                         NaN
# GERMANY                                                             Stefan W. Hell
# HUNGARY                                                                        NaN
# ISRAEL                                                                         NaN
# ITALY                                                                          NaN
# JAPAN                                                                          NaN
# MEXICO                                                                         NaN
# NETHERLANDS (THE)                                                              NaN
# NORWAY                                                                         NaN
# Not awarded                                                                    NaN
# POLAND                                                                         NaN
# RUSSIAN FEDERATION (THE)                                                       NaN
# SWEDEN                                                                         NaN
# SWITZERLAND                                                                    NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                             NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)          Eric Betzig William E. Moerner
#
#                                                                                  \
# Year_of_award                                                              2015
# Country_of_birth
# ARGENTINA                                                                   NaN
# AUSTRALIA                                                                   NaN
# AUSTRIA                                                                     NaN
# BELGIUM                                                                     NaN
# BOSNIA AND HERZEGOVINA                                                      NaN
# CANADA                                                                      NaN
# CROATIA                                                                     NaN
# CZECHIA                                                                     NaN
# DENMARK                                                                     NaN
# FINLAND                                                                     NaN
# FRANCE                                                                      NaN
# GERMANY                                                                     NaN
# HUNGARY                                                                     NaN
# ISRAEL                                                                      NaN
# ITALY                                                                       NaN
# JAPAN                                                                       NaN
# MEXICO                                                                      NaN
# NETHERLANDS (THE)                                                           NaN
# NORWAY                                                                      NaN
# Not awarded                                                                 NaN
# POLAND                                                                      NaN
# RUSSIAN FEDERATION (THE)                                                    NaN
# SWEDEN                                                            Tomas Lindahl
# SWITZERLAND                                                                 NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                          NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)          Paul L. Modrich Aziz Sancar
#
#                                                                          \
# Year_of_award                                                      2016
# Country_of_birth
# ARGENTINA                                                           NaN
# AUSTRALIA                                                           NaN
# AUSTRIA                                                             NaN
# BELGIUM                                                             NaN
# BOSNIA AND HERZEGOVINA                                              NaN
# CANADA                                                              NaN
# CROATIA                                                             NaN
# CZECHIA                                                             NaN
# DENMARK                                                             NaN
# FINLAND                                                             NaN
# FRANCE                                              Jean-Pierre Sauvage
# GERMANY                                                             NaN
# HUNGARY                                                             NaN
# ISRAEL                                                              NaN
# ITALY                                                               NaN
# JAPAN                                                               NaN
# MEXICO                                                              NaN
# NETHERLANDS (THE)                                           Ben Feringa
# NORWAY                                                              NaN
# Not awarded                                                         NaN
# POLAND                                                              NaN
# RUSSIAN FEDERATION (THE)                                            NaN
# SWEDEN                                                              NaN
# SWITZERLAND                                                         NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...      Fraser Stoddart
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                          NaN
#
#                                                                        \
# Year_of_award                                                    2017
# Country_of_birth
# ARGENTINA                                                         NaN
# AUSTRALIA                                                         NaN
# AUSTRIA                                                           NaN
# BELGIUM                                                           NaN
# BOSNIA AND HERZEGOVINA                                            NaN
# CANADA                                                            NaN
# CROATIA                                                           NaN
# CZECHIA                                                           NaN
# DENMARK                                                           NaN
# FINLAND                                                           NaN
# FRANCE                                                            NaN
# GERMANY                                                 Joachim Frank
# HUNGARY                                                           NaN
# ISRAEL                                                            NaN
# ITALY                                                             NaN
# JAPAN                                                             NaN
# MEXICO                                                            NaN
# NETHERLANDS (THE)                                                 NaN
# NORWAY                                                            NaN
# Not awarded                                                       NaN
# POLAND                                                            NaN
# RUSSIAN FEDERATION (THE)                                          NaN
# SWEDEN                                                            NaN
# SWITZERLAND                                          Jacques Dubochet
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...  Richard Henderson
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                        NaN
#
#                                                                                  \
# Year_of_award                                                              2018
# Country_of_birth
# ARGENTINA                                                                   NaN
# AUSTRALIA                                                                   NaN
# AUSTRIA                                                                     NaN
# BELGIUM                                                                     NaN
# BOSNIA AND HERZEGOVINA                                                      NaN
# CANADA                                                                      NaN
# CROATIA                                                                     NaN
# CZECHIA                                                                     NaN
# DENMARK                                                                     NaN
# FINLAND                                                                     NaN
# FRANCE                                                                      NaN
# GERMANY                                                                     NaN
# HUNGARY                                                                     NaN
# ISRAEL                                                                      NaN
# ITALY                                                                       NaN
# JAPAN                                                                       NaN
# MEXICO                                                                      NaN
# NETHERLANDS (THE)                                                           NaN
# NORWAY                                                                      NaN
# Not awarded                                                                 NaN
# POLAND                                                                      NaN
# RUSSIAN FEDERATION (THE)                                                    NaN
# SWEDEN                                                                      NaN
# SWITZERLAND                                                                 NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...           Sir Gregory Winter
# UNITED STATES MINOR OUTLYING ISLANDS (THE)          Frances Arnold George Smith
#
#                                                                             \
# Year_of_award                                                         2019
# Country_of_birth
# ARGENTINA                                                              NaN
# AUSTRALIA                                                              NaN
# AUSTRIA                                                                NaN
# BELGIUM                                                                NaN
# BOSNIA AND HERZEGOVINA                                                 NaN
# CANADA                                                                 NaN
# CROATIA                                                                NaN
# CZECHIA                                                                NaN
# DENMARK                                                                NaN
# FINLAND                                                                NaN
# FRANCE                                                                 NaN
# GERMANY                                                                NaN
# HUNGARY                                                                NaN
# ISRAEL                                                                 NaN
# ITALY                                                                  NaN
# JAPAN                                                        Akira Yoshino
# MEXICO                                                                 NaN
# NETHERLANDS (THE)                                                      NaN
# NORWAY                                                                 NaN
# Not awarded                                                            NaN
# POLAND                                                                 NaN
# RUSSIAN FEDERATION (THE)                                               NaN
# SWEDEN                                                                 NaN
# SWITZERLAND                                                            NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...  M. Stanley Whittingham
# UNITED STATES MINOR OUTLYING ISLANDS (THE)              John B. Goodenough
#
#                                                                             \
# Year_of_award                                                         2020
# Country_of_birth
# ARGENTINA                                                              NaN
# AUSTRALIA                                                              NaN
# AUSTRIA                                                                NaN
# BELGIUM                                                                NaN
# BOSNIA AND HERZEGOVINA                                                 NaN
# CANADA                                                                 NaN
# CROATIA                                                                NaN
# CZECHIA                                                                NaN
# DENMARK                                                                NaN
# FINLAND                                                                NaN
# FRANCE                                              Emmanuelle Charpentier
# GERMANY                                                                NaN
# HUNGARY                                                                NaN
# ISRAEL                                                                 NaN
# ITALY                                                                  NaN
# JAPAN                                                                  NaN
# MEXICO                                                                 NaN
# NETHERLANDS (THE)                                                      NaN
# NORWAY                                                                 NaN
# Not awarded                                                            NaN
# POLAND                                                                 NaN
# RUSSIAN FEDERATION (THE)                                               NaN
# SWEDEN                                                                 NaN
# SWITZERLAND                                                            NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                     NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                 Jennifer Doudna
#
#                                                                           \
# Year_of_award                                                       2021
# Country_of_birth
# ARGENTINA                                                            NaN
# AUSTRALIA                                                            NaN
# AUSTRIA                                                              NaN
# BELGIUM                                                              NaN
# BOSNIA AND HERZEGOVINA                                               NaN
# CANADA                                                               NaN
# CROATIA                                                              NaN
# CZECHIA                                                              NaN
# DENMARK                                                              NaN
# FINLAND                                                              NaN
# FRANCE                                                               NaN
# GERMANY                                                    Benjamin List
# HUNGARY                                                              NaN
# ISRAEL                                                               NaN
# ITALY                                                                NaN
# JAPAN                                                                NaN
# MEXICO                                                               NaN
# NETHERLANDS (THE)                                                    NaN
# NORWAY                                                               NaN
# Not awarded                                                          NaN
# POLAND                                                               NaN
# RUSSIAN FEDERATION (THE)                                             NaN
# SWEDEN                                                               NaN
# SWITZERLAND                                                          NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...  David W.C. MacMillan
# UNITED STATES MINOR OUTLYING ISLANDS (THE)                           NaN
#
#                                                                                          \
# Year_of_award                                                                      2022
# Country_of_birth
# ARGENTINA                                                                           NaN
# AUSTRALIA                                                                           NaN
# AUSTRIA                                                                             NaN
# BELGIUM                                                                             NaN
# BOSNIA AND HERZEGOVINA                                                              NaN
# CANADA                                                                              NaN
# CROATIA                                                                             NaN
# CZECHIA                                                                             NaN
# DENMARK                                                                   Morten Meldal
# FINLAND                                                                             NaN
# FRANCE                                                                              NaN
# GERMANY                                                                             NaN
# HUNGARY                                                                             NaN
# ISRAEL                                                                              NaN
# ITALY                                                                               NaN
# JAPAN                                                                               NaN
# MEXICO                                                                              NaN
# NETHERLANDS (THE)                                                                   NaN
# NORWAY                                                                              NaN
# Not awarded                                                                         NaN
# POLAND                                                                              NaN
# RUSSIAN FEDERATION (THE)                                                            NaN
# SWEDEN                                                                              NaN
# SWITZERLAND                                                                         NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                                  NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)          Carolyn Bertozzi K. Barry Sharpless
#
#
# Year_of_award                                                                  2023
# Country_of_birth
# ARGENTINA                                                                       NaN
# AUSTRALIA                                                                       NaN
# AUSTRIA                                                                         NaN
# BELGIUM                                                                         NaN
# BOSNIA AND HERZEGOVINA                                                          NaN
# CANADA                                                                          NaN
# CROATIA                                                                         NaN
# CZECHIA                                                                         NaN
# DENMARK                                                                         NaN
# FINLAND                                                                         NaN
# FRANCE                                                                          NaN
# GERMANY                                                                         NaN
# HUNGARY                                                                         NaN
# ISRAEL                                                                          NaN
# ITALY                                                                           NaN
# JAPAN                                                                           NaN
# MEXICO                                                                          NaN
# NETHERLANDS (THE)                                                               NaN
# NORWAY                                                                          NaN
# Not awarded                                                                     NaN
# POLAND                                                                          NaN
# RUSSIAN FEDERATION (THE)                                              Alexey Ekimov
# SWEDEN                                                                          NaN
# SWITZERLAND                                                                     NaN
# UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IR...                              NaN
# UNITED STATES MINOR OUTLYING ISLANDS (THE)          Moungi G. Bawendi Louis E. Brus
#
# [26 rows x 123 columns]
